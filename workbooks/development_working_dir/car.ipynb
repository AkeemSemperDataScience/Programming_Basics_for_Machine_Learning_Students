# %%
import pandas as pd

# %% [markdown]
# # Cars

# %%
df = pd.read_csv('../../data/cars.csv')
df.head()
# Out:
#           ID Make     Model  Year          Trim  \
# 0  401935490  BMW  3 Series  2023          330i
# 1  401953112  BMW  3 Series  2023          330e
# 2  401953111  BMW  3 Series  2023         M340i
# 3  401953113  BMW  3 Series  2023  M340i xDrive
# 4  401953115  BMW  3 Series  2023   330e xDrive
#
#                                   Trim (description) Base MSRP Base Invoice  \
# 0                330i 4dr Sedan (2.0L 4cyl Turbo 8A)  $42,300      $39,840
# 1  330e 4dr Sedan (2.0L 4cyl Turbo gas/electric p...  $43,300      $40,770
# 2  M340i 4dr Sedan (3.0L 6cyl Turbo gas/electric ...  $54,850      $51,510
# 3  M340i xDrive 4dr Sedan AWD (3.0L 6cyl Turbo ga...  $56,850      $53,370
# 4  330e xDrive 4dr Sedan AWD (2.0L 4cyl Turbo gas...  $45,300      $42,630
#
#                                      Colors exterior  \
# 0  Portimao Blue Metallic(66,89,154);Mineral Whit...
# 1  Portimao Blue Metallic(66,89,154);Mineral Whit...
# 2  Portimao Blue Metallic(66,89,154);Mineral Whit...
# 3  Portimao Blue Metallic(66,89,154);Mineral Whit...
# 4  Portimao Blue Metallic(66,89,154);Mineral Whit...
#
#                                      Colors interior  ... Towing and hauling  \
# 0  Canberra Beige SensaTec, leatherette(217,211,1...  ...                NaN
# 1  Canberra Beige SensaTec, leatherette(217,211,1...  ...                NaN
# 2  Canberra Beige SensaTec, leatherette(217,211,1...  ...                NaN
# 3  Canberra Beige SensaTec, leatherette(217,211,1...  ...                NaN
# 4  Canberra Beige SensaTec, leatherette(217,211,1...  ...                NaN
#
#    Safety features  Packages  Exterior options  Interior options  \
# 0              NaN       NaN               NaN               NaN
# 1              NaN       NaN               NaN               NaN
# 2              NaN       NaN               NaN               NaN
# 3              NaN       NaN               NaN               NaN
# 4              NaN       NaN               NaN               NaN
#
#    Mechanical options  Domestic / imported  Country of origin  \
# 0                 NaN             Imported            Germany
# 1                 NaN             Imported            Germany
# 2                 NaN             Imported            Germany
# 3                 NaN             Imported            Germany
# 4                 NaN             Imported            Germany
#
#    Car classification  Platform code / generation number
# 0         Compact car                                G20
# 1         Compact car                                G20
# 2         Compact car                                G20
# 3         Compact car                                G20
# 4         Compact car                                G20
#
# [5 rows x 112 columns]

# %%
df.describe(include='all').T
# Out:
#                                    count unique  \
# ID                                 621.0    NaN
# Make                                 621      3
# Model                                621      4
# Year                               621.0    NaN
# Trim                                 621     89
# ...                                  ...    ...
# Mechanical options                   234     90
# Domestic / imported                  621      2
# Country of origin                    621      3
# Car classification                   621      2
# Platform code / generation number    621     17
#
#                                                                                  top  \
# ID                                                                               NaN
# Make                                                                            Ford
# Model                                                                          F-150
# Year                                                                             NaN
# Trim                                                                             XLT
# ...                                                                              ...
# Mechanical options                 \n                            6-Speed STEPTRON...
# Domestic / imported                                                         Domestic
# Country of origin                                                      United States
# Car classification                                            Full-size pickup truck
# Platform code / generation number                                           13th gen
#
#                                   freq              mean               std  \
# ID                                 NaN  175937546.723027  155997246.034976
# Make                               344               NaN               NaN
# Model                              336               NaN               NaN
# Year                               NaN       2009.305958          9.736353
# Trim                                90               NaN               NaN
# ...                                ...               ...               ...
# Mechanical options                  15               NaN               NaN
# Domestic / imported                344               NaN               NaN
# Country of origin                  344               NaN               NaN
# Car classification                 344               NaN               NaN
# Platform code / generation number   84               NaN               NaN
#
#                                       min          25%          50%  \
# ID                                   32.0  100003663.0  101171222.0
# Make                                  NaN          NaN          NaN
# Model                                 NaN          NaN          NaN
# Year                               1990.0       2002.0       2010.0
# Trim                                  NaN          NaN          NaN
# ...                                   ...          ...          ...
# Mechanical options                    NaN          NaN          NaN
# Domestic / imported                   NaN          NaN          NaN
# Country of origin                     NaN          NaN          NaN
# Car classification                    NaN          NaN          NaN
# Platform code / generation number     NaN          NaN          NaN
#
#                                            75%          max
# ID                                 401729246.0  401954474.0
# Make                                       NaN          NaN
# Model                                      NaN          NaN
# Year                                    2018.0       2023.0
# Trim                                       NaN          NaN
# ...                                        ...          ...
# Mechanical options                         NaN          NaN
# Domestic / imported                        NaN          NaN
# Country of origin                          NaN          NaN
# Car classification                         NaN          NaN
# Platform code / generation number          NaN          NaN
#
# [112 rows x 11 columns]

# %%
cols = df.columns
for col in cols:
    print(col)
# Out:
# ID
# Make
# Model
# Year
# Trim
# Trim (description)
# Base MSRP
# Base Invoice
# Colors exterior
# Colors interior
# Body type
# Doors
# Total seating
# Length (in)
# Width (in)
# Height (in)
# Wheelbase (in)
# Front track (in)
# Rear track (in)
# Ground clearance (in)
# Angle of approach (degrees)
# Angle of departure (degrees)
# Turning circle (ft)
# Drag coefficient (Cd)
# EPA interior volume (cu ft)
# Cargo capacity (cu ft)
# Maximum cargo capacity (cu ft)
# Curb weight (lbs)
# Gross weight (lbs)
# Maximum payload (lbs)
# Maximum towing capacity (lbs)
# Cylinders
# Engine size (l)
# Horsepower (HP)
# Horsepower (rpm)
# Torque (ft-lbs)
# Torque (rpm)
# Valves
# Valve timing
# Cam type
# Drive type
# Transmission
# Engine type
# Fuel type
# Fuel tank capacity (gal)
# EPA combined MPG
# EPA city/highway MPG
# Range in miles (city/hwy)
# EPA combined MPGe
# EPA city/highway MPGe
# EPA electricity range (mi)
# EPA kWh/100 mi
# EPA time to charge battery (at 240V) (hr)
# Battery capacity (kWh)
# Front head room (in)
# Front hip room (in)
# Front leg room (in)
# Front shoulder room (in)
# Rear head room (in)
# Rear hip room (in)
# Rear leg room (in)
# Rear shoulder room (in)
# Basic
# Drivetrain
# Roadside
# Rust
# Source JSON
# Source URL
# Image URL
# NHTSA Overall Rating
# Scorecard Overall
# Scorecard Driving
# Scorecard Comfort
# Scorecard Interior
# Scorecard Utility
# Scorecard Technology
# Expert rating - Our verdict
# Expert rating - Driving
# Expert rating - Comfort
# Expert rating - Interior
# Expert rating - Technology
# Expert rating - Storage
# Expert rating - Economy
# Expert rating - Value
# Expert rating - Wildcard
# Old trim
# Old description
# Images URL
# Suspension
# Front seats
# Rear seats
# Power features
# Instrumentation
# Convenience
# Comfort
# Memorized settings
# In car entertainment
# Roof and glass
# Body
# Truck features
# Tires and wheels
# Doors2
# Towing and hauling
# Safety features
# Packages
# Exterior options
# Interior options
# Mechanical options
# Domestic / imported
# Country of origin
# Car classification
# Platform code / generation number

# %%
get_cols = ["Make", "Model", "Year", "Trim", "Trim (description)", 
            "Base MSRP", "Body type", "Doors", "Total seating", 
            "Curb weight (lbs)", "Cylinders", "Engine size (l)", "Horsepower (HP)", 
            "Torque (ft-lbs)", "Drive type", "Transmission", "Engine type", 
            "Fuel type", "EPA combined MPG", "Country of origin", "Car classification"]
df2 = df[get_cols]
df2.head()
# Out:
#   Make     Model  Year          Trim  \
# 0  BMW  3 Series  2023          330i
# 1  BMW  3 Series  2023          330e
# 2  BMW  3 Series  2023         M340i
# 3  BMW  3 Series  2023  M340i xDrive
# 4  BMW  3 Series  2023   330e xDrive
#
#                                   Trim (description) Base MSRP Body type  \
# 0                330i 4dr Sedan (2.0L 4cyl Turbo 8A)  $42,300      Sedan
# 1  330e 4dr Sedan (2.0L 4cyl Turbo gas/electric p...  $43,300      Sedan
# 2  M340i 4dr Sedan (3.0L 6cyl Turbo gas/electric ...  $54,850      Sedan
# 3  M340i xDrive 4dr Sedan AWD (3.0L 6cyl Turbo ga...  $56,850      Sedan
# 4  330e xDrive 4dr Sedan AWD (2.0L 4cyl Turbo gas...  $45,300      Sedan
#
#    Doors  Total seating  Curb weight (lbs)  ... Engine size (l)  \
# 0      4            5.0             3536.0  ...             2.0
# 1      4            5.0             4180.0  ...             2.0
# 2      4            5.0             3834.0  ...             3.0
# 3      4            5.0             3951.0  ...             3.0
# 4      4            5.0             4083.0  ...             2.0
#
#    Horsepower (HP)  Torque (ft-lbs)        Drive type  \
# 0              255            295.0  rear wheel drive
# 1              288            310.0  rear wheel drive
# 2              382            368.0  rear wheel drive
# 3              382            368.0   all wheel drive
# 4              288            310.0   all wheel drive
#
#                   Transmission     Engine type                    Fuel type  \
# 0  8-speed shiftable automatic             gas  premium unleaded (required)
# 1  8-speed shiftable automatic  plug-in hybrid  premium unleaded (required)
# 2  8-speed shiftable automatic     mild hybrid  premium unleaded (required)
# 3  8-speed shiftable automatic     mild hybrid  premium unleaded (required)
# 4  8-speed shiftable automatic  plug-in hybrid  premium unleaded (required)
#
#   EPA combined MPG  Country of origin Car classification
# 0             29.0            Germany        Compact car
# 1              NaN            Germany        Compact car
# 2             26.0            Germany        Compact car
# 3             26.0            Germany        Compact car
# 4              NaN            Germany        Compact car
#
# [5 rows x 21 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 621 entries, 0 to 620
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                621 non-null    object
#  1   Model               621 non-null    object
#  2   Year                621 non-null    int64
#  3   Trim                621 non-null    object
#  4   Trim (description)  621 non-null    object
#  5   Base MSRP           469 non-null    object
#  6   Body type           621 non-null    object
#  7   Doors               621 non-null    int64
#  8   Total seating       469 non-null    float64
#  9   Curb weight (lbs)   546 non-null    float64
#  10  Cylinders           613 non-null    object
#  11  Engine size (l)     613 non-null    float64
#  12  Horsepower (HP)     621 non-null    int64
#  13  Torque (ft-lbs)     568 non-null    float64
#  14  Drive type          621 non-null    object
#  15  Transmission        595 non-null    object
#  16  Engine type         621 non-null    object
#  17  Fuel type           621 non-null    object
#  18  EPA combined MPG    608 non-null    float64
#  19  Country of origin   621 non-null    object
#  20  Car classification  621 non-null    object
# dtypes: float64(5), int64(3), object(13)
# memory usage: 102.0+ KB

# %%
df2.describe(include="all").T
# Out:
#                     count unique  \
# Make                  621      3
# Model                 621      4
# Year                621.0    NaN
# Trim                  621     89
# Trim (description)    621    428
# Base MSRP             469    425
# Body type             621      9
# Doors               621.0    NaN
# Total seating       469.0    NaN
# Curb weight (lbs)   546.0    NaN
# Cylinders             613      4
# Engine size (l)     613.0    NaN
# Horsepower (HP)     621.0    NaN
# Torque (ft-lbs)     568.0    NaN
# Drive type            621      4
# Transmission          595     11
# Engine type           621      7
# Fuel type             621      6
# EPA combined MPG    608.0    NaN
# Country of origin     621      3
# Car classification    621      2
#
#                                                                   top freq  \
# Make                                                             Ford  344
# Model                                                           F-150  336
# Year                                                              NaN  NaN
# Trim                                                              XLT   90
# Trim (description)  Two 4dr Hatchback (1.8L 4cyl gas/electric hybr...    8
# Base MSRP                                                    $24,200     4
# Body type                                           Truck (SuperCrew)  108
# Doors                                                             NaN  NaN
# Total seating                                                     NaN  NaN
# Curb weight (lbs)                                                 NaN  NaN
# Cylinders                                                          I6  191
# Engine size (l)                                                   NaN  NaN
# Horsepower (HP)                                                   NaN  NaN
# Torque (ft-lbs)                                                   NaN  NaN
# Drive type                                           rear wheel drive  297
# Transmission                                           5-speed manual  140
# Engine type                                                       gas  425
# Fuel type                                            regular unleaded  374
# EPA combined MPG                                                  NaN  NaN
# Country of origin                                       United States  344
# Car classification                             Full-size pickup truck  344
#
#                            mean         std     min     25%     50%     75%  \
# Make                        NaN         NaN     NaN     NaN     NaN     NaN
# Model                       NaN         NaN     NaN     NaN     NaN     NaN
# Year                2009.305958    9.736353  1990.0  2002.0  2010.0  2018.0
# Trim                        NaN         NaN     NaN     NaN     NaN     NaN
# Trim (description)          NaN         NaN     NaN     NaN     NaN     NaN
# Base MSRP                   NaN         NaN     NaN     NaN     NaN     NaN
# Body type                   NaN         NaN     NaN     NaN     NaN     NaN
# Doors                  3.504026    1.125396     2.0     2.0     4.0     4.0
# Total seating          4.991471    0.884295     3.0     5.0     5.0     6.0
# Curb weight (lbs)   4036.749084  821.814351  2745.0  3287.5  3906.5  4668.0
# Cylinders                   NaN         NaN     NaN     NaN     NaN     NaN
# Engine size (l)        3.482708    1.259186     1.5     2.5     3.3     4.9
# Horsepower (HP)       241.89533   94.474371   110.0   145.0   231.0   300.0
# Torque (ft-lbs)      284.806338  106.066372    82.0   253.0   265.0   365.0
# Drive type                  NaN         NaN     NaN     NaN     NaN     NaN
# Transmission                NaN         NaN     NaN     NaN     NaN     NaN
# Engine type                 NaN         NaN     NaN     NaN     NaN     NaN
# Fuel type                   NaN         NaN     NaN     NaN     NaN     NaN
# EPA combined MPG      23.641447   12.039052    12.0    16.0    20.0    22.0
# Country of origin           NaN         NaN     NaN     NaN     NaN     NaN
# Car classification          NaN         NaN     NaN     NaN     NaN     NaN
#
#                        max
# Make                   NaN
# Model                  NaN
# Year                2023.0
# Trim                   NaN
# Trim (description)     NaN
# Base MSRP              NaN
# Body type              NaN
# Doors                  5.0
# Total seating          6.0
# Curb weight (lbs)   5863.0
# Cylinders              NaN
# Engine size (l)        5.8
# Horsepower (HP)      563.0
# Torque (ft-lbs)      775.0
# Drive type             NaN
# Transmission           NaN
# Engine type            NaN
# Fuel type              NaN
# EPA combined MPG      56.0
# Country of origin      NaN
# Car classification     NaN

# %% [markdown]
# ## Create Objects

# %%
df2["Car classification"].value_counts()
# Out:
# Full-size pickup truck    344
# Compact car               277
# Name: Car classification, dtype: int64

# %%
df2["Engine type"].value_counts()
# Out:
# gas                425
# hybrid              96
# flex-fuel (FFV)     74
# diesel              10
# electric             8
# plug-in hybrid       4
# mild hybrid          4
# Name: Engine type, dtype: int64

# %%
def Car():

    def __init__(self, make, model, **kwargs):
        self.make = make
        self.model = model
        for key, value in kwargs.items():
            setattr(self, key, value)
    #def
