# %%
import os
import sys
import pandas as pd

# %% [markdown]
# # File Management 2
#
# ## Pandas File Access
#
# We've already looked at our main tool for reading data from disk, the file read/write functionality in Pandas. When reading datasets this is normally all we need. Inside the read_csv function the Pandas people have either created all the file access stuff that they need to read a CSV or, more likely, they repurposed and extended some os library functions to do the work for them.

# %%
df = pd.read_csv("../data/chipotle.tsv", sep="\t")
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ## OS and File Read/Write
#
# We can also use the `os` module to do some basic file management. OS is a library that allows us to interact with the operating system on our local computer. Recall that our Python programs run inside an environment setup by the Python install on our computer. This means that as we work we are "inside" that separate environment and we can't directly interact with the underlying computer. The os library, and functions such as read_csv from other libraries, are a tool that allows us to bridge this gap. The os library that is presented to us gives us an assortment of commands to do things like delete files or change the directory we're using. The library's functions are then translated into the correct actions for the actual computer, and passed on to that computer, when the code is run in the Python environment. This also allows for Python code to be portable, or able to run with few to no changes, on different types of computers - I am using a Mac, most of you are probably using a PC, and we can also use a Unix/Linux based system like Google Colab. The code we write can work on all of those environments because of this abstraction, and in each case, the actions triggered by the os module will be different depending on the underlying operating system of the machine. In practice, many of the user-friendly libraries that we might use to access files or folders is built on top of the os module, so we often avoid needing to get into the weeds ourselves.
#
# We can use the `os` module to do things like:
# <ul>
#     <li>Get the current working directory</li>
#     <li>Change the current working directory</li>
#     <li>Get a list of files in a directory</li>
#     <li>Create a new directory</li>
#     <li>Remove a directory</li>
#     <li>Remove a file</li>
# </ul>
#
# First though, let's get some info about our system. Everyone will get totally different results here - I'm on a MacBook Air running MacOS, and I assume most of you have some variety of a PC running Windows. If you've ever seen any of those website things that tells you, "You are running Windows 10 in Edmonton, Ab..." this is a similar idea. The os.uname() function reaches out to the computer and retrieves some of it's identifying information for us.

# %%
for a in os.uname():
    print(a)
# Out:
# Darwin
# Akeems-MacBook-Air.local
# 22.5.0
# Darwin Kernel Version 22.5.0: Mon Apr 24 20:52:43 PDT 2023; root:xnu-8796.121.2~5/RELEASE_ARM64_T8112
# arm64

# %% [markdown]
# We can also get much more info by looking at the environment variables. These are variables that are set in the operating system and are available to any program running on the computer. These admittedly not frequently relevant to us doing some data science work, but it is a good example of connecting to the system. One thing that can matter to us is the PATH variable, which (roughly) lists all the places the system will look for programs to run. This is how the system knows where to find Python, for example - its in one of those places - as are all the programs installed on your machine.

# %%
os.environ
# Out:
# environ{'COMMAND_MODE': 'unix2003',
#         'CONDA_DEFAULT_ENV': 'ml_2',
#         'CONDA_EXE': '/Users/akeem/anaconda3/bin/conda',
#         'CONDA_PREFIX': '/Users/akeem/anaconda3/envs/ml_2',
#         'CONDA_PROMPT_MODIFIER': '(ml_2) ',
#         'CONDA_PYTHON_EXE': '/Users/akeem/anaconda3/bin/python',
#         'CONDA_SHLVL': '2',
#         'HOME': '/Users/akeem',
#         'LOGNAME': 'akeem',
#         'MallocNanoZone': '0',
#         'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined',
#         'PATH': '/Users/akeem/anaconda3/envs/ml_2/bin:/Users/akeem/anaconda3/condabin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Applications/quarto/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin',
#         'PWD': '/',
#         'SHELL': '/bin/zsh',
#         'SHLVL': '2',
#         'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.a4PvHL9x8B/Listeners',
#         'TMPDIR': '/var/folders/p1/m8wtcgx57417hx9d_r110ctw0000gn/T/',
#         'USER': 'akeem',
#         'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#         'VSCODE_CODE_CACHE_PATH': '/Users/akeem/Library/Application Support/Code/CachedData/fee1edb8d6d72a0ddff41e5f71a671c23ed924b9',
#         'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost',
#         'VSCODE_CWD': '/',
#         'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#         'VSCODE_IPC_HOOK': '/Users/akeem/Library/Application Support/Code/1.92-main.sock',
#         'VSCODE_NLS_CONFIG': '{"userLocale":"en-us","osLocale":"en-ca","resolvedLanguage":"en","defaultMessagesFile":"/Applications/Visual Studio Code.app/Contents/Resources/app/out/nls.messages.json","locale":"en","availableLanguages":{}}',
#         'VSCODE_PID': '2725',
#         'XPC_FLAGS': '0x0',
#         'XPC_SERVICE_NAME': '0',
#         '_': '/Users/akeem/anaconda3/envs/ml_2/bin/python',
#         '__CFBundleIdentifier': 'com.microsoft.VSCode',
#         '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x52',
#         'ELECTRON_RUN_AS_NODE': '1',
#         'VSCODE_DOTNET_INSTALL_TOOL_ORIGINAL_HOME': '/Users/akeem',
#         'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1',
#         'VSCODE_L10N_BUNDLE_LOCATION': '',
#         'PYTHONUNBUFFERED': '1',
#         'PYTHONIOENCODING': 'utf-8',
#         '_CE_CONDA': '',
#         'CONDA_PREFIX_1': '/Users/akeem/anaconda3',
#         'CONDA_ROOT': '/Users/akeem/anaconda3',
#         '_CE_M': '',
#         'LC_CTYPE': 'UTF-8',
#         'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#         'PYTHON_FROZEN_MODULES': 'on',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
os.environ["PATH"].split(":")
# Out:
# ['/Users/akeem/anaconda3/envs/ml_2/bin',
#  '/Users/akeem/anaconda3/condabin',
#  '/usr/local/bin',
#  '/System/Cryptexes/App/usr/bin',
#  '/usr/bin',
#  '/bin',
#  '/usr/sbin',
#  '/sbin',
#  '/Applications/quarto/bin',
#  '/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin',
#  '/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin',
#  '/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin']

# %% [markdown]
# The shutil module is a partner to the os one, and provides some other functions. Among those, we can see disk usage.

# %%
import shutil
shutil.disk_usage("/")
# Out:
# usage(total=994662584320, used=408281825280, free=586380759040)

# %% [markdown]
# ## Folder Management
#
# The OS library also provides for an assortment of folder management functions. We can use these to create, rename, and delete folders.
#
# When using large datasets it is very common to have our data distributed over several folders. For example, if we are doing image recognition we might have a folder for "dogs", another with "cars", and another with "rutabagas". To construct our dataset we need to navigate over all of these folders and read in the files, using os and/or some similar libraries.
#
# Some common folder actions are:
# <ul>
# <li> os.mkdir() - create a new folder </li>
# <li> os.rename() - rename a folder </li>
# <li> os.rmdir() - remove a folder </li>
# <li> os.getcwd() - get the current working directory </li>
# <li> os.chdir() - change the current working directory </li>
# <li> os.listdir() - list the contents of a directory </li>
# </ul>

# %%
os.getcwd()
# Out:
# '/Users/akeem/Nextcloud/GitHubReps/2024_summer/Instructor/Programming_Basics_for_ML/workbooks'

# %% [markdown]
# <b>Note:</b> when using these functions, you need to be careful about where you are in the file system. In particular, the folder location doesn't reset itself automatically if you rerun everything. We need to restart the environment to reset the working directory, or navigate ourselves back to the correct location. The above command got the current working directory back from the Python environment, which in turn got it from the operating system. If we make a change to that directory, then rerun the above cell, we aren't "reset" to the original where we were when we started the program. To do that, we'd need to restart the environment, which would kill this current world in which our program is running, and generate a brand new one.
#
# Here I'm going to capture the current folder name and then move one level up, and back down.

# %%
org_fold = os.getcwd()
tmp = os.getcwd().split("/")[-1]
print(tmp)
os.chdir("../")
os.getcwd()
os.chdir(tmp)
# Out:
# workbooks

# %% [markdown]
# #### Handling File System Data
#
# We can also capture some of this information, and use it as a variable in our code that we can use to navigate the file system. For example, when grabbing the working directory above we stored it as a string and used the split command to break it into a hierarchy of folder names. Below we can pull the files in a folder and that data is returned in a list. If we have code where we need to jump around from folder to folder, we can use this list to help us navigate. For example, if we have a folder structure like this:
#
# ```
# data
#     - dogs
#         - dog1.jpg
#         - dog2.jpg
#         - dog3.jpg
#     - cats
#         - cat1.jpg
#         - cat2.jpg
#         - cat3.jpg
#     - rutabagas
#         - rutabaga1.jpg
#         - rutabaga2.jpg
#         - rutabaga3.jpg
# ```
# Our "base" folder is the data folder, and the subfolders inside are where we'll likely need to do all of our work. We can keep this map of the folder structure in some data structure, then we can use that info to move around. For example, we can find out where we are, visit each subfolder to do some work, and then move back to the base folder.

# %%
# Capture file list
# Print 5
#<b>Bonus:</b> at some point when we looked at strings, someone asked about putting a newline in an f string. I was wrong, it can work like this, no workarounds needed. 
file_list = os.listdir()
print(f"Number of flies: {len(file_list)}\n")
for file in range(5):
    print(file_list[file])
# Out:
# Number of flies: 66
#
# 002_conditional_statements_sol.ipynb
# 021_big_review.ipynb
# 001a_python_example.py
# 010_class_comments.ipynb
# 011_looping_2_data.ipynb

# %% [markdown]
# ### Get Your Walk On
#
# ![Walk](../images/walk.gif "Walk")
#
# Manually navigating folder structures is pretty useful, but it also sucks and is error prone. The os.walk() function makes this a bit easier for us by doing the "walking" from one folder to another seamlessly.
#
# The os.walk() function returns a generator object, which is a special type of object that we can use to iterate over the contents of a folder. The generator object is a tuple, with the first element being the current folder, the second element being a list of subfolders, and the third element being a list of files. We can use this to iterate over the contents of a folder, and then iterate over the contents of each subfolder, and so on.
#
# The walk function returns a 3 part tuple for us:
# <ul>
#     <li> The current folder </li>
#     <li> A list of subfolders </li>
#     <li> A list of files </li>
# </ul>
#
# We can also use a flag to set if our walker will go top down or bottom up. The default is top down, which means we start at the top level folder and work our way down to the files. If we set the flag to False, we start at the bottom and work our way up. In practice, we pertty much always want top down - we have a folder inside our repository, such as "data" or "logs", and we want to navigate into it. Going the other direction moves "up" and if we leave our repository, that's the computer at large, and it could be anything. This may be useful if you're making an installed application, but most things that we're working on are contained to a specific location, so drilling down is normal.

# %%
walker = os.walk("../")
moonwalker = os.walk("../", topdown=False)

# %%
for root, directories, files, in walker:
    print(f"Root: {root}")
    print(f"Directories: {directories}")
    print(f"Files: {files}")
# Out:
# Root: ../
# Directories: ['supplementary_practice_workbooks', 'reference_material', 'images', 'course_material', '.git', 'data', 'workbooks']
# Files: ['.DS_Store', 'README.md', '.gitignore']
# Root: ../supplementary_practice_workbooks
# Directories: ['moodle_exercises']
# Files: ['Lecture23_24_workbook.ipynb', 'Lecture22_Regression_Tuning.ipynb', 'Lecture18_beginning_classification_part_2.ipynb', 'Lecture_09_10_Workbook.ipynb', 'Lecture05_conditions_loops.ipynb', 'Lecture21_Multiple_Regression.ipynb', 'Lecture20_pipeline_part_2.ipynb', 'Lecture15_beginning_regression_part_1.ipynb', 'Lecture02_basics.ipynb', 'Lecture13-14_Intro_ML.ipynb', 'Lecture21_22_workbook.ipynb', 'Lecture16_beginning_regression_part_2.ipynb', 'Lecture12_probability.ipynb', 'Lecture07-08_Pandas.ipynb', 'Lecture15-16_workbook.ipynb', 'Lecture09_data_wrangling_pandas_I.ipynb', 'Lecture11_descriptive_statistics.ipynb', 'Lecture05_workbook.ipynb', 'Lecture07-08_workbook.ipynb', 'Lecture02_workbook.ipynb', 'Lecture10_data_wrangling_pandas_II.ipynb', 'Lecture06_numpy.ipynb', 'Lecture03_workbook.ipynb', 'Lecture04_arrays_files.ipynb', 'Lecture04_workbook.ipynb', 'Lecture06_workbook.ipynb', 'Lecture13_workbook.ipynb', 'Lecture19_pipeline_impute_part_1.ipynb', 'Lecture23-24_classification_methods.ipynb', 'Lecture17_beginning_classification_part_1.ipynb', 'Lecture14_workbook.ipynb', 'Lecture03_datatypes.ipynb', 'data_dictionary.ipynb', 'Lecture11_12_Workbook.ipynb', 'Lecture19_20_workbook.ipynb', 'Lecture17_18_Workbook.ipynb']
# Root: ../supplementary_practice_workbooks/moodle_exercises
# Directories: []
# Files: ['2_Examples.ipynb', '4_Day_1.ipynb', '1_racing cars.ipynb', '1_exapmles.ipynb', '2_Day_1.ipynb', '11_Inheritance_.ipynb', '6 Day 1 - Lists and Functions.ipynb', '2_More Exercises.ipynb', 'Week_9_Day_Sets_and_Dictionaries.ipynb', '10_Day_1_Object_Oriented_Programming.ipynb', '7_Day_1_Files_and_exceptions.ipynb', '3 Day 1.ipynb']
# Root: ../reference_material
# Directories: ['docs_and_guides', 'slides']
# Files: ['.DS_Store']
# Root: ../reference_material/docs_and_guides
# Directories: []
# Files: ['jupyter_markdown.pdf', 'small_python_cheat_sheet.pdf', 'data_eng.pdf', 'Super_Inherit.pdf', 'python_decorators.pdf', 'pythonlearn.pdf', 'large_python_cheat_sheet.pdf', 'Intro_to_Machine_Learning_in_Python.pdf', '20_python_concepts.pdf']
# Root: ../reference_material/slides
# Directories: ['zz_OLD']
# Files: ['006_classes_obj_1.pptx', '023_asn2_work_time.pptx', '.DS_Store', '001_intro_setup.pptx', '~$006_classes_obj_1.pptx', 'inheritance.pptx', '019_test_driven.pptx', 'os_system.pptx', '003_loops.pptx', '025_UI.pptx', '002_vars_and_control.pptx', '008_recursion.pptx', '021_review_verification.pptx', '012_algo_interface_errors.pptx', '007_other_data_structures.pptx', '020_regular_expressions.pptx', '005_file_access.pptx', '018_cards_2.pptx', '017_arg_kwarg.pptx', '004_functions.pptx', '013_arrays.pptx', '014_bulk_actions.pptx', '026_refactor.pptx', '009_comments_enum.pptx', '015_overload.pptx', '~$005_file_access.pptx', '024_search_sort.pptx', '022_mult_inh_abc.pptx']
# Root: ../reference_material/slides/zz_OLD
# Directories: ['Repository', 'Used']
# Files: ['.DS_Store']
# Root: ../reference_material/slides/zz_OLD/Repository
# Directories: []
# Files: ['Lecture06_numpy.pptx', 'Lecture01_Introduction.pptx', 'Lecture16_LEAST_ ANGLE_REGRESSION.pdf', 'Lecture13_Intro_ML.pptx', '016_Pipelines.pptx', 'Lecture02_python_intro.pptx', '014_Forest_Ensamble.pptx', 'Lecture04_arrays_files.pptx', '008_Error_Bias_Variance.pptx', 'Lecture07-08_Pandas.pptx', 'Lecture21-22_Para_Tuning.pptx', 'Lecture14_ml_basics.pptx', 'Lecture17-18_Classification.pptx', '008_Classification_Log_Reg.pptx', '004_ml_basics.pptx', 'Lecture19_Pipelines.pptx', '018_Gridsearch.pptx', 'Lecture23-24_Classification_Tuning.ppt', '002_Intro Machine Learning.pptx', '010_log_reg_2_imbalanced.pptx', '012_Trees.pptx', 'Lecture05_conditions_loops.pptx', 'Lecture03_datatypes.pptx', '006_Linear_Least_Squares.pptx', 'Lecture15-16_Regression.pptx']
# Root: ../reference_material/slides/zz_OLD/Used
# Directories: []
# Files: ['015_log_reg.pptx', '013_categorical_features.pptx', '007_arrays.pptx', '022_Feature_Selection.pptx', '008_review_1.pptx', '005_Pandas_Datasheet.pptx', '009_Correlation_Scatter.pptx', '006_Basic_Descriptive_Stats.pptx', '014_pipelines.pptx', '012_median_and_scaling.pptx', '003_loops.pptx', '023_Basis_and_Regularization.pptx', '002_vars_and_control.pptx', '018_regression_review_stats.pptx', '017_Gridsearch.pptx', '011_Linear_Least_Squares.pptx', '021_Forest_Ensamble.pptx', '004_functions.pptx', '016_log_reg_2.pptx', '021_regression_tree.pptx', '020_unsupervised_cluster.pptx', '010_Errors.pptx', '019_Trees_over_under.pptx', '020_Trees_2_Regularization.pptx']
# Root: ../images
# Directories: []
# Files: ['enumeration.png', 'repr.png', 'inheritance.png', 'make_dict.jpg', 'array_calendar.png', 'theon.jpeg', 'map.webp', 'binary_linear_search.gif', 'paths.png', 'python-multiple-inheritance.png', 'marvin.png', 'walk.gif', 'multilevel_inheritance.png', 'formatting.png', 'inh_types.webp', 'regex.png', 'series_dataframe.png', 'fact_breakdown.png', 'nested_for.png', 'sorting-algorithm.gif', 'abc_collections.png', 'stump.png', 'weak_learn.png', 'pandas.png', 'logic-gates.webp', 'for_loop.jpg', 'while_loop.png', 'for_loop.png', 'encapsulation.jpg', 'if_else.png', 'array_memory.png', 'map.png', 'sorting.png', 'array.png', 'df.webp', 'list_comprehension.png', 'multiple_inh.png', 'files_os.png', 'harvard_grades.webp', 'early_stopping.png', 'example_dropdown.png', 'inheritance_types.jpg', 'histogram.png', 'regex_cheatsheet.webp', 'algorithm.jpg', 'set_operations.png', 'numpy_indexing.png', 'nested_if.png', 'map_inputs.png', 'new_method.png', 'arg_kwarg.png', 'string_index.png', 'lambda.png', 'hash-table.png', 'markdown.webp', 'file_permissions.png', 'python-sets.jpg', 'factorial.png', 'array_reshape.jpeg', 'binary_vs_linear.jpg', '3d_array.webp', 'try_except.png', 'hierarchial_inheritance.png', 'seek.webp', 'multilevel_inheritance.webp', 'iterator.png', 'var_scope.webp', 'dict_list.png', 'recursion.png', 'dict_list.jpg']
# Root: ../course_material
# Directories: ['labs', 'assignments', 'exams', 'documents']
# Files: ['.DS_Store', 'syllabus_1241.docx', 'syllabus_1231.docx']
# Root: ../course_material/labs
# Directories: ['lab1', 'lab6', 'lab0', 'lab5', 'lab2', 'lab3', 'lab4']
# Files: ['.DS_Store', 'test.csv', 'output.csv', 'inputs.csv', 'output2.csv']
# Root: ../course_material/labs/lab1
# Directories: ['github']
# Files: ['SAMP_SOL_Lab_1_test_generator.py', 'requirements.txt', 'test_harness.py', 'generate_tests.ipynb', 'README.md', 'START_Lab_1.py', 'SAMP_SOL_Lab_1.py', 'SAMP_SOL_Lab_1.ipynb', 'SAMP_SOL_responses.csv']
# Root: ../course_material/labs/lab1/github
# Directories: ['test', 'workflows']
# Files: ['test_file2.txt', 'test_file1.txt']
# Root: ../course_material/labs/lab1/github/test
# Directories: []
# Files: ['test_csv_load.py']
# Root: ../course_material/labs/lab1/github/workflows
# Directories: []
# Files: ['classroom.yml', 'copy_template_files.yml']
# Root: ../course_material/labs/lab6
# Directories: ['github']
# Files: ['requirements.txt', 'SAMP_SOL_Lab_6.py', 'SAMP_SOL_Lab_6.ipynb', 'Lab_6_Q_5.py']
# Root: ../course_material/labs/lab6/github
# Directories: []
# Files: ['classroom.yml', 'test_START_Lab_2.py']
# Root: ../course_material/labs/lab0
# Directories: ['github']
# Files: ['requirements.txt', 'test_harness.py', 'SAMP_SOL_Lab_0.py', 'README.md', 'START_Lab_0.py']
# Root: ../course_material/labs/lab0/github
# Directories: ['test', 'workflows']
# Files: ['.DS_Store']
# Root: ../course_material/labs/lab0/github/test
# Directories: []
# Files: ['test_csv_load.py']
# Root: ../course_material/labs/lab0/github/workflows
# Directories: []
# Files: ['classroom.yml', 'copy_template_files.yml']
# Root: ../course_material/labs/lab5
# Directories: ['github']
# Files: ['requirements.txt', 'Lab5_input.txt', 'SAMP_SOL_Lab_5.py', 'SAMP_SOL_Lab_5.ipynb']
# Root: ../course_material/labs/lab5/github
# Directories: []
# Files: ['classroom.yml', 'test_START_Lab_2.py']
# Root: ../course_material/labs/lab2
# Directories: ['__pycache__', 'github']
# Files: ['requirements.txt', 'test_harness.py', 'SAMP_SOL_Lab_2.py', 'START_Lab_2.py', 'SAMP_SOL_Lab_2_test_generator.py', 'SAMP_SOL_Lab_2.ipynb', 'SAMP_SOL_responses.csv']
# Root: ../course_material/labs/lab2/__pycache__
# Directories: []
# Files: ['SAMP_SOL_Lab_2.cpython-310.pyc', 'START_Lab_2.cpython-310.pyc']
# Root: ../course_material/labs/lab2/github
# Directories: []
# Files: ['classroom.yml', 'test_START_Lab_2.py']
# Root: ../course_material/labs/lab3
# Directories: ['__pycache__', 'github']
# Files: ['requirements.txt', 'test_harness.py', 'START_Lab_3.py', 'SAMP_SOL_Lab_3.py', 'SAMP_SOL_Lab_3.ipynb']
# Root: ../course_material/labs/lab3/__pycache__
# Directories: []
# Files: ['START_Lab_3.cpython-310.pyc']
# Root: ../course_material/labs/lab3/github
# Directories: []
# Files: ['classroom.yml']
# Root: ../course_material/labs/lab4
# Directories: ['github']
# Files: ['requirements.txt', 'test_SAMP_SOL_Lab_4.py', 'SAMP_SOL_Lab_4.py', 'START_Lab_4.py', 'SAMP_SOL_Lab_4.ipynb']
# Root: ../course_material/labs/lab4/github
# Directories: []
# Files: ['classroom.yml', 'test_START_Lab_2.py']
# Root: ../course_material/assignments
# Directories: ['asn1', 'asn2']
# Files: ['.DS_Store']
# Root: ../course_material/assignments/asn1
# Directories: ['data']
# Files: ['requirements.txt', 'asn_1.py', 'START_Asn_1.ipynb', 'README.md', 'START_asn_1.py', 'Asn_1_1241.ipynb', 'Assignment_1_sample_sol.ipynb']
# Root: ../course_material/assignments/asn1/data
# Directories: []
# Files: ['Car Electronics.csv', 'Strength Training.csv']
# Root: ../course_material/assignments/asn2
# Directories: ['data']
# Files: ['START_Asn_2.ipynb', 'requirements.txt', 'input_output.png', 'README.md', 'example_results.png']
# Root: ../course_material/assignments/asn2/data
# Directories: []
# Files: ['output.csv', 'inputs.csv']
# Root: ../course_material/exams
# Directories: ['exam_3', 'exam_2', 'exam_1']
# Files: []
# Root: ../course_material/exams/exam_3
# Directories: []
# Files: []
# Root: ../course_material/exams/exam_2
# Directories: []
# Files: []
# Root: ../course_material/exams/exam_1
# Directories: ['applied', 'written']
# Files: []
# Root: ../course_material/exams/exam_1/applied
# Directories: []
# Files: ['test_harness.py', 'exam_1.py']
# Root: ../course_material/exams/exam_1/written
# Directories: []
# Files: []
# Root: ../course_material/documents
# Directories: []
# Files: []
# Root: ../.git
# Directories: ['objects', 'info', 'logs', 'hooks', 'refs']
# Files: ['ORIG_HEAD', 'config', 'HEAD', 'description', 'index', 'packed-refs', 'COMMIT_EDITMSG', 'FETCH_HEAD']
# Root: ../.git/objects
# Directories: ['61', '0d', '59', '92', '0c', '66', '3e', '68', '57', '3b', '03', '9b', '9e', '04', '6a', '32', '35', '69', '3c', '56', '51', '3d', '58', '67', '0b', '93', '94', '0e', '60', '5f', '33', '05', '9d', '9c', '02', 'a4', 'a3', 'b5', 'b2', 'd9', 'ac', 'ad', 'd7', 'd0', 'be', 'b3', 'df', 'da', 'b4', 'a5', 'bd', 'd1', 'bc', 'ae', 'd8', 'ab', 'e5', 'e2', 'f4', 'f3', 'eb', 'c7', 'c0', 'ee', 'c9', 'fc', 'fd', 'f2', 'f5', 'e3', 'cf', 'ca', 'e4', 'fe', 'c8', 'fb', 'ed', 'c1', 'ec', '4e', '18', '27', '4b', 'pack', '11', '7d', '29', '7c', '16', '42', '89', '45', '1f', '73', '87', '80', '74', '1a', '28', '17', '7b', '8f', '8a', '7e', '10', '19', '4c', '26', '21', '4d', '75', '81', '44', '2a', '2f', '43', '9f', '6b', '07', '38', '00', '6e', '9a', '36', '5c', '09', '31', 'info', '91', '62', '3a', '54', '53', '3f', '30', '5b', '37', '6d', '01', '06', '39', '99', '52', '55', '0f', '0a', '90', 'bf', 'd3', 'ba', 'a0', 'a7', 'b8', 'b1', 'dd', 'dc', 'b6', 'a9', 'd2', 'aa', 'af', 'b7', 'db', 'a8', 'de', 'b0', 'a6', 'b9', 'ef', 'c4', 'ea', 'e1', 'cd', 'cc', 'e6', 'f9', 'f0', 'f7', 'e8', 'fa', 'ff', 'c5', 'c2', 'f6', 'e9', 'e7', 'cb', 'f8', 'ce', 'e0', '46', '2c', '79', '2d', '41', '83', '1b', '77', '70', '24', '4f', '8d', '15', '12', '8c', '85', '1d', '71', '76', '1c', '82', '49', '40', '2e', '47', '78', '8b', '13', '7f', '7a', '8e', '22', '25']
# Files: []
# Root: ../.git/objects/61
# Directories: []
# Files: ['e659c266b2b319e7b1f899a99d2fb2ee6dcf86', 'ac6f5d0879f456f5abb49b9f3dbd242f2107f7', '4f285270b40090e5870d3a03e15a78e022906c', 'dead95e3c724af49338fa0ed5d0f528374e6f2']
# Root: ../.git/objects/0d
# Directories: []
# Files: ['c138c437efb97d48583d0cce81c2d94d6a8d7a', 'c80adf56277d95330cd8e6ae4503db00b08be5']
# Root: ../.git/objects/59
# Directories: []
# Files: ['5c23fa45daf7cf09b1ae6cfb12cf22c16bbb6a']
# Root: ../.git/objects/92
# Directories: []
# Files: ['4b1b1fef07076d331c45e296b930fac32e0a2a']
# Root: ../.git/objects/0c
# Directories: []
# Files: ['0edd0464b02e8cec3efe92674191d25d8b2aa1', '9cd4f3a31838b798f93944d1201f5abed83623']
# Root: ../.git/objects/66
# Directories: []
# Files: ['fabafdc4198a5f37f84e22c769cc3430f64672', '94f6ac50e590fb5623fefca255a840bc901541', '05769a8357287377023d5057ab182e867bb5f3']
# Root: ../.git/objects/3e
# Directories: []
# Files: ['87c671586eeaa81849667fc052b94f4bc6b9a6']
# Root: ../.git/objects/68
# Directories: []
# Files: ['3714dee73fa918632dc1c4239987cecb9075bb']
# Root: ../.git/objects/57
# Directories: []
# Files: ['08ad17e91fd4c60d4d45452ad447ceb5a89fa8']
# Root: ../.git/objects/3b
# Directories: []
# Files: ['df2514c9afd4786d0a3dad3db10af74e9cb4d1', '2d42e5ddca074660220a68e1aa4ee24c3cae9b', '52a7ec1f3017f6c1b16883a2a84dada8e22a56', 'a7d9507067098f87cd174273997de164ef6f2d']
# Root: ../.git/objects/03
# Directories: []
# Files: ['4d1c994d3a3434b45995f5938a3387f87c2a7d', '01062ed90617e5a1206b9b27bc4ee8a33053ff', '17859af3e2255343e70ada094a72711660e09a']
# Root: ../.git/objects/9b
# Directories: []
# Files: ['04d8eff15eb2085e1f5dae6f7ddce9ce84d3a4']
# Root: ../.git/objects/9e
# Directories: []
# Files: ['69ccce9a276a835f112f5c894022cd4b583b9e', 'e13d57d00cc70610cfd5f652138047d931d755', 'c10bab19be936d48dc226f2e79033a2578dd39', '8857bc9fe3e17aa125b0da4f7dcfbc091824b7']
# Root: ../.git/objects/04
# Directories: []
# Files: ['e94a56eb896e0badec29d0f4220383b178e19b', 'fcb300ad8f1d69611ab74ec9e45c670872fd51', '9c520c7359742a0ab5b13f2e4fea844aeadd57']
# Root: ../.git/objects/6a
# Directories: []
# Files: ['59505a19225fda929aa133550cb19ba3042f83', '9671884e19961c7f81997680bb86410563fce9', 'b6f7fe6b3d4d38caacd20b3c723d27ce17804a']
# Root: ../.git/objects/32
# Directories: []
# Files: ['8e0089b13192a4f029f01e892fb0e0312cab77']
# Root: ../.git/objects/35
# Directories: []
# Files: ['7f14301be59ece47ab6ff8a89984a6165adf27']
# Root: ../.git/objects/69
# Directories: []
# Files: ['0903887cac2b03279360617418c866c69d95e8', '106f2691eacb52bd9e2d22f0fd57fb2c1e6fba']
# Root: ../.git/objects/3c
# Directories: []
# Files: ['0c8d7fc4dd3dec723ad6ff49668a12255bdebe']
# Root: ../.git/objects/56
# Directories: []
# Files: ['b63687cb158fb79899ce24be9cb8ac0b9f7f54', '65ca9402f817386a03a9d2f4eb3e941efd2463', '8d85e4b1aabb4927eae63e82f4c123e8c97906', '806eb70e4a5814ddfcabf4beab699bf4773f44', '1ec27d3de36092b7a6d908ca0362804c8913dc']
# Root: ../.git/objects/51
# Directories: []
# Files: ['77abb39afe63850ba799c8e95e04b12cf5decd']
# Root: ../.git/objects/3d
# Directories: []
# Files: ['d957125f7bce5cb4ac0d8a145c1eafc51a3b56', '05dd46b4ebf1ce3d91a03a41afe55055d36331', '7d63b649b7174bda8624ae64052e59ae391d58']
# Root: ../.git/objects/58
# Directories: []
# Files: ['a30f94b8867dc61d10e5fb6af3ea1ce2b902b3']
# Root: ../.git/objects/67
# Directories: []
# Files: ['8f8c059317dbd3aa080fca3faaf4239d31c52e', 'f5274ff7968327ee96fea29a6e4f6fc5f68812', '8a384e544d8eac88124d874c13823c5ef531c1', 'c84c3481577886e74f1723a795765fe433d550']
# Root: ../.git/objects/0b
# Directories: []
# Files: ['6d147f8c8c28c753f4b5b565eb878527ba44ce', '5f3c206efebe2f77ff080fdb52fefd99aaa83a', '6593d7df34139b71bdc94e500dcd2ee53faa29']
# Root: ../.git/objects/93
# Directories: []
# Files: ['bfc9d9c1891d85be48692e956eb621bac00960', '01eef4e5de8baa9d82a6e19be685fde265aa5d']
# Root: ../.git/objects/94
# Directories: []
# Files: ['40305c3b3f3088890fa85973eb61e83256ac54']
# Root: ../.git/objects/0e
# Directories: []
# Files: ['30af43fd12db754f4061ee2d2571c42ea8ff72']
# Root: ../.git/objects/60
# Directories: []
# Files: ['d186fba6b859899658b61a311dbe455f3c4f92']
# Root: ../.git/objects/5f
# Directories: []
# Files: ['fe3f87c9e80737cdd7b838bd35e791f3bef825']
# Root: ../.git/objects/33
# Directories: []
# Files: ['2a8077191d197a9f73d6ee9d0a33ba86706c6f', 'dbd6a2482b660b5ae4bedbcbe07eea61b70a6d']
# Root: ../.git/objects/05
# Directories: []
# Files: ['3d9e8f74d56f054e46703f3c08cabe00bc8243']
# Root: ../.git/objects/9d
# Directories: []
# Files: ['38152832c8a875355c220c0407326027ce9504', '6c17ee9aaa9fd2ea0d621082d0a47739657bec', '20f2dfdc0b781b5a188d39a2c1f74cce70ec41', '1878275470fd5098c6f74927c6d020790bf655']
# Root: ../.git/objects/9c
# Directories: []
# Files: ['af295ca232d32ee89c70a6aa77db93dda891ef', 'b2a13222a2eb103b15afadbbfbadca36bf5879', '942c98dabad3037e94ef0548a9e13c13e22df9', 'fb30fb5b6f7b702bdd088d7cbf256620cd0b9d', 'a15eabdbb85f373cc9106a5db4e33f58db7fb6']
# Root: ../.git/objects/02
# Directories: []
# Files: ['47d8fd06e2d58db21f0b9319f3e76863ded940', '0b9d48e740c7a1db7eb03fce3d456849eca1c7', '30e1d4b0d586fdfa683d2e8d256194f8e1c556']
# Root: ../.git/objects/a4
# Directories: []
# Files: ['95466de75a9569e40d3834c6c8ac864ad4b1e3', '2695e9985999a326076b31f513468c7507227f']
# Root: ../.git/objects/a3
# Directories: []
# Files: ['56d95594dc05eee219b3548d02ddf49c2bb5c5']
# Root: ../.git/objects/b5
# Directories: []
# Files: ['02e90617629d025b0b988bd0d714ecbd98e5a5']
# Root: ../.git/objects/b2
# Directories: []
# Files: ['e9681d3aed5712c585a7ee36a64fffb30d6170', '7e3a178b412425e5250b08b3345f0c620b4aca', '2fdde6586908862161cb7f90b0d974a4829e4e', '1b3967f62d66d1f3dee32c8e5a855ae09dc516']
# Root: ../.git/objects/d9
# Directories: []
# Files: ['09ac0eb6446b23b5e363ab59e11ce151ee8c13', 'd5e6f300c7e6fb327360acb15684e15f514790', 'df797d312b4a745b3621629890c5b7e89adf6b']
# Root: ../.git/objects/ac
# Directories: []
# Files: ['e1da11f6f6186c87ce7d35cc9e3d133da4d8a1']
# Root: ../.git/objects/ad
# Directories: []
# Files: ['ec98e2bfcd95642786de251778a11492256ed8', '3f5a0b212ea39256d2298ed7e152fbfb794037']
# Root: ../.git/objects/d7
# Directories: []
# Files: ['934321fe4cb23016930bb6dba31e710c2c0a87', 'c5684ef4b262d93bb8ab517793ab244ccc7846', 'e28ad540f11eb7399d5c00c6095368683af7a7', '6018a9d86b252a6e314a08a071da2debd10683', '794344f18dc5c0291e30876b7aad167d9a8e50']
# Root: ../.git/objects/d0
# Directories: []
# Files: ['b4be2121ef1c95debda278f68f1b3633960dbc']
# Root: ../.git/objects/be
# Directories: []
# Files: ['ae2519f925710fe1c6aff809a9acdb9b10913a', '535c91518743c06cc881f0b0de432053cc9d26', 'ab014de798a6fb274d648468cdf01ffcfc96d8', 'aeaaf406f7a7aafb5e6ffea08be403b806952c']
# Root: ../.git/objects/b3
# Directories: []
# Files: ['4434fbd51fc88078e6c743e7e4aa0e6ed85c33']
# Root: ../.git/objects/df
# Directories: []
# Files: ['c48b07f87a453e380b02eb3c36900d7d0d3b91', '1bafb2f6577ed61613b9dc64b82324ccb0e624', 'f55dbc93c1aac2fb36f14f2ebf59d6062f8c0b', '3e9d898ea7f07ae4e09e2fb65b9caa5f341337', '61cb04f9225536b6b4bba49d5f6534d376c4a0']
# Root: ../.git/objects/da
# Directories: []
# Files: ['848bbd05e4e2c1fb9a3407698284f1e5f0d70d', '315a9f90ab756d41de877cd1d74935fe6f2115']
# Root: ../.git/objects/b4
# Directories: []
# Files: ['ac34d2cb84da6b1952cc2636889525138de82a']
# Root: ../.git/objects/a5
# Directories: []
# Files: ['7c4879ce2a1674f1b46a6873f731ba57aa79ef', '015021d1f4feb8c58c5810b21e160a36793308', '193647a4dbef4a2e9e7ef3cb96e595db99cee6']
# Root: ../.git/objects/bd
# Directories: []
# Files: ['6ba503b059fb813095866a0a9e0d34320a68c9', '078cdc17536ee7cd5be04b13d882c86c75157f', '9cb7f2e4aaf326541fd3799d05b7fa6f3a7c43']
# Root: ../.git/objects/d1
# Directories: []
# Files: ['512b8fba30cca8dd3c9088a19e5e375256c100', 'ba01f7a2fd9c1563a4ecbe4e75955d2736d961']
# Root: ../.git/objects/bc
# Directories: []
# Files: ['c4da554dcb1ab3e695f5180528b5298736c491', '674ae4620397f6ff215f51cf5bfc3d7908cacc', '805f55506537076b80e38fc21d8b20ec75a67a']
# Root: ../.git/objects/ae
# Directories: []
# Files: ['fefd0f76517c6a9f59ea8a54846d749bb3e338']
# Root: ../.git/objects/d8
# Directories: []
# Files: ['d9af94f65f9ce72d4e6ce56826207c132fe89b', '4e358a40f2dfc5b74b96811fc6edcdb5773ea5']
# Root: ../.git/objects/ab
# Directories: []
# Files: ['30d45754ac1417776f6447a051d3fa1729401c']
# Root: ../.git/objects/e5
# Directories: []
# Files: ['630d634129cf2e60d57a85e133f1e1dffcf15b', 'f31d5ab4db53c3ea706fb7010c8449cffacd21']
# Root: ../.git/objects/e2
# Directories: []
# Files: ['66bfaf39432caf61be939968daf423eab47a63', 'cba7198e0b6c271e7df763a46f52887d50867f', '8438222f5b718aaf3d75504a13f1547fd3c0e3']
# Root: ../.git/objects/f4
# Directories: []
# Files: ['5f7b570c6ad7cbbbc49bafbaa0b8538f515891']
# Root: ../.git/objects/f3
# Directories: []
# Files: ['d33a886aedf997e602f5e59e5a98925e6b81d6']
# Root: ../.git/objects/eb
# Directories: []
# Files: ['795b238df8ba6ed3a12cb56dd5e4792be963d0', 'e54063008983a94d3d8ae56e53270a1c19ec57']
# Root: ../.git/objects/c7
# Directories: []
# Files: ['46f68bd946d71e0e07c24c43ab09084e2bbb66', '911c52da0a9e755ced99f839610ca131513d15', '9ba8b5694e72b892387c6ca7fb36e48cb1fa48']
# Root: ../.git/objects/c0
# Directories: []
# Files: ['1f9df030d4d03fe38b316373a607fdfb2879bf', '5ef9d9be2e49955f56eca7441564bfdf66001c']
# Root: ../.git/objects/ee
# Directories: []
# Files: ['daecd06f45558d77c7ba4662e2d030cdeaa48e', '77ac766832ee70a859b9297271ed282e91a958']
# Root: ../.git/objects/c9
# Directories: []
# Files: ['bdf1a03d553af5dc5ce6e32468fe32889c23de', '0b07ff2fa68cdaf4c9be3a699969aabe65dbe0', 'da16777b78a71f6e65f8a4d3826576e15194ec', 'effd056cffd53cae1bd84e1e66fef2db678572', '65c5286a0fc7e4307576b4c3177d1317847182']
# Root: ../.git/objects/fc
# Directories: []
# Files: ['d3f49022d14b8392fff032aa9e0b568a8951de']
# Root: ../.git/objects/fd
# Directories: []
# Files: ['76b1fda62440e064363ec538d7e94fd367bbba', '29f58d733a4b05a7bd3e55664cdc493c2d31a1', 'ed88dc9c5dc8b0b935d3162ab485ff10438b56', 'b25ea3b5a18d195f63a667613f95fbd839e622']
# Root: ../.git/objects/f2
# Directories: []
# Files: ['0f7ecd8eaa0ebb4adc274df61034f0f850ca5e']
# Root: ../.git/objects/f5
# Directories: []
# Files: ['dbecce5b5b5d51f465fd9810b337fe9a3ae5aa', '35c3d379c3d06a6ad5fab289e9c96ade0619e3', 'ddc8c8948547bbcdd1030e601388d52dbfdf93']
# Root: ../.git/objects/e3
# Directories: []
# Files: ['1be5698113398a9102846304986e462f5ecf7d']
# Root: ../.git/objects/cf
# Directories: []
# Files: ['7725ed4aedef3410845f5b453d28ad5fa80fda']
# Root: ../.git/objects/ca
# Directories: []
# Files: ['0880052e889f289c8ba73401fbd6a70d753b4e', '80053f6dcaa3c94df5381b36221ba42d5aac74']
# Root: ../.git/objects/e4
# Directories: []
# Files: ['29b8ccf665db9cd290b81fefb3b7855ce4a9b1', 'bd0d8ba2727805853fd33f26422066770b5068']
# Root: ../.git/objects/fe
# Directories: []
# Files: ['c1f4edbc617e39c9904aba63b16d243d3d7561']
# Root: ../.git/objects/c8
# Directories: []
# Files: ['825a54953c6e8db389f4b6bdf3b431a2684315', '76cf9682de5feaf0e4ba2180365142ffcbbc52']
# Root: ../.git/objects/fb
# Directories: []
# Files: ['08bdb17d51acc34bd8e9ea112b520c44697801', '04a083e97704e229bf87bb7339e35d00615aa1']
# Root: ../.git/objects/ed
# Directories: []
# Files: ['288db018feab943a8a6565ba3a8402bffc6ec7']
# Root: ../.git/objects/c1
# Directories: []
# Files: ['94adc79e2e511b608acef76ea6df276f0a6007']
# Root: ../.git/objects/ec
# Directories: []
# Files: ['68e4c7d7d6f123b2aa404e68fd4fad554fa415']
# Root: ../.git/objects/4e
# Directories: []
# Files: ['653ae2690515202d05d74936bd5b7b813fbbb6', 'd4dac2bc54cd223ace5f01a290e1e0bc873909']
# Root: ../.git/objects/18
# Directories: []
# Files: ['c51241f94383b19495b6cef290ea79bec7af23', '233b4d58ca8f7228bdc4b5287c995f620597ca']
# Root: ../.git/objects/27
# Directories: []
# Files: ['824ab1048021a6d242249b992e4cb557576491']
# Root: ../.git/objects/4b
# Directories: []
# Files: ['ac42f78a394e1786579d8ebbd90221610a545d', '825dc642cb6eb9a060e54bf8d69288fbee4904']
# Root: ../.git/objects/pack
# Directories: []
# Files: ['pack-9138131734f5b7b3d99f07ded3a95df286c8081d.idx', 'pack-9138131734f5b7b3d99f07ded3a95df286c8081d.pack']
# Root: ../.git/objects/11
# Directories: []
# Files: ['95bd7cef80bdab7259d5dd20a84f771110c4f6']
# Root: ../.git/objects/7d
# Directories: []
# Files: ['274fdf492978c45a2ccbc63809c447f0eaa7d4', 'f6abf18c6aec5345bd9bd0d17fb3325e9c77ad']
# Root: ../.git/objects/29
# Directories: []
# Files: ['14eebadce6c57bb2c1bf40175ec5fd4c634eff', 'd5336f68894270dd1f13db01991042de7e898d']
# Root: ../.git/objects/7c
# Directories: []
# Files: ['2e73f6752fc2cc97c786dadee872ea5ffaa5c9', 'fc8bb4a9b44f9e777475839f4646da330faec4']
# Root: ../.git/objects/16
# Directories: []
# Files: ['1d35530f8b0d46414ad048691e2d65e35cc66c', 'db25f2a44bceafaef743cb1632fdfc7e6ed23e', '0e707ffe998b2176e0b879d320c7262fe786af']
# Root: ../.git/objects/42
# Directories: []
# Files: ['07249a6bcd5c99078518d2783d6877159edc78', '5495d72adbaf197b318150a4e13af9b09e838c']
# Root: ../.git/objects/89
# Directories: []
# Files: ['21f818f0621e2a2f93076fd449acb0b0afd5be', '54e1c7689138a06ac351c142c742950175bf4f', '8a504439d2bb8028f5e271f95d1db3447722d6', '64da606302028096e86ee7de4e8e21d5f6fbe1']
# Root: ../.git/objects/45
# Directories: []
# Files: ['b286665119cb64766371b22c4ff4dc5d179018']
# Root: ../.git/objects/1f
# Directories: []
# Files: ['700f203e21a749f2e6bebcc6c15476a9a47a2e', '2eaefcc19b3b556cd49d0513c2e81406c6f4f7', '7c7122faa77cad1abc31761664a724327b9d89', '90c166f44445aa3acbe17d90833fe26fcb8735']
# Root: ../.git/objects/73
# Directories: []
# Files: ['1445de9a9e3345a534d6923a630a2f2d300316', '7fad407bd595ade3e1c7e6511fb1125f2e60ea']
# Root: ../.git/objects/87
# Directories: []
# Files: ['fc64505248c4f51a9ed324441038f549f846a9']
# Root: ../.git/objects/80
# Directories: []
# Files: ['e70b8ad208d4e11429ef5333d471267f5616e2', '10bc18d83b3dc3d57c3819e130c21200247ce8', 'a985c200728faf39784a87f825588b439d2d92']
# Root: ../.git/objects/74
# Directories: []
# Files: ['6f42deb7975fe9c3983d0e61a749bfd877ecf3', '3e62dba485418a3022e22411b071571705a823', '8f5c06981bc86dc4e24bcefd511e005df3f206', '3abaf7cd2c8a760e09d895d51e928cf6468b9f']
# Root: ../.git/objects/1a
# Directories: []
# Files: ['3458dbe854a581d5f7cd105d279174882e503d', '221cc71266d0569238a74e68d3fab1fbabf901']
# Root: ../.git/objects/28
# Directories: []
# Files: ['3b253f9015d3b7246e31577129361bfc6a83ed', '1131d45a068f865395838ea495d8be9dfe60c2', '211084deb4cda4fea1f71d578a334792d43100']
# Root: ../.git/objects/17
# Directories: []
# Files: ['8b0516e47fd5d37233d79444397afa257af159', '6ffd1c5c86ad06834ba099072b0fe9ca5600c6']
# Root: ../.git/objects/7b
# Directories: []
# Files: ['26c4689564f901489773a388d11ae521919a7a', 'b2d8cf27bd223e0d505ab496e2398989b55496', 'de4393e17274b5227d47b6862ae2d7d08d6d0b']
# Root: ../.git/objects/8f
# Directories: []
# Files: ['508c957292928e5779884f58c76688c6104415', '861d42aae7729e95e8e630b52b362cd567fa46', '8e610ddd88f45d4df174ebf9e9d25eafbab052']
# Root: ../.git/objects/8a
# Directories: []
# Files: ['13602604df5095e60c8438a38afc46f0ff265d', '3cb598887262f2d38ab374e91bf38eb18004ce']
# Root: ../.git/objects/7e
# Directories: []
# Files: ['06bc3391f3d04209223881b61a1b88d7354f4d', '1b96985e64b14508028d656c56b50c72d9fd58', '8982b60ac6e9adbb1602915c6a131c3cdad2b1']
# Root: ../.git/objects/10
# Directories: []
# Files: ['06a325d1ba1b7a31404c905a225bc91ace1fb9']
# Root: ../.git/objects/19
# Directories: []
# Files: ['00e2cd8b34e3cd254f2caa953037a9ee9344e8']
# Root: ../.git/objects/4c
# Directories: []
# Files: ['86c61705769fcf23ade78fd4d797a12d65c277']
# Root: ../.git/objects/26
# Directories: []
# Files: ['165ae1abd3275919f13f1f130ac78ed48e112a']
# Root: ../.git/objects/21
# Directories: []
# Files: ['9033c44864192a2d7dd658d141f2b22a064ea4']
# Root: ../.git/objects/4d
# Directories: []
# Files: ['1dc2b5ace52a3c4afff220b222776bed36ff0c']
# Root: ../.git/objects/75
# Directories: []
# Files: ['f509b83556b79b96f4d30a6a846e85fe9383d5', '1d04b82b7679137f2fbc244960bfc5fdb84c68']
# Root: ../.git/objects/81
# Directories: []
# Files: ['984e5b62b04aec73478e04165495d43c8847c6']
# Root: ../.git/objects/44
# Directories: []
# Files: ['7171061b65c56f6c655c0c4e9ce496bec28655', '43548882296fd55fcd22362a420c4d83d698be', 'f133ef552b9cb3264145e590b390f8f015378c', 'b0138c77ec272150493918da839b26cce03af6']
# Root: ../.git/objects/2a
# Directories: []
# Files: ['f2f0d633a9f3da9c8550d115e3f0fb059b4113', '3b616a1c93c3d4406f3ca712aedb611de31bba']
# Root: ../.git/objects/2f
# Directories: []
# Files: ['464e1781f0fc3e6319a17f63341f161cd16c77', '0a27fb49e7fd0e6183f0b74601e38740fc7698', '2fc16ddd8570b545747982c75701b81be0803a']
# Root: ../.git/objects/43
# Directories: []
# Files: ['5f664a23010ef72885ff34de819026050836b5', 'ec19961b9f66858785e53d9386b766fa3525dd', '917d0c375cc688356bddcea20e0c88c3bcdad5', '8992f7f6cc4cce8c6dd4b5343c02f4562d2da7']
# Root: ../.git/objects/9f
# Directories: []
# Files: ['e37ea54cd2995e2e56ce1c3921b258631100eb']
# Root: ../.git/objects/6b
# Directories: []
# Files: ['d7615d654c09f1f4ab08b007eeaec64d8f63d7', '9c65493622d57e9394a6707679709ada6cfe50', '43ce7d9ded6abb18e71191e1ca6a89fcd49e39']
# Root: ../.git/objects/07
# Directories: []
# Files: ['e792402a1f59f14f02bb418a9fe6a6a6d7b8ea', '5b90f76f8f7afaa40bd09c61bc01c57d9547f3', 'eb62a6c2917e358dbab6b1214c07f85e6710c9']
# Root: ../.git/objects/38
# Directories: []
# Files: ['cc106e81e9b3887689e56689e5eb060386d09a']
# Root: ../.git/objects/00
# Directories: []
# Files: ['8a19420a29bf7cb62f5860aa3039e0b3418301', '3eeee14e1574ac87eee4867121d382ee0a7643']
# Root: ../.git/objects/6e
# Directories: []
# Files: ['58fb545dc05bb27a0ccd6c5bccb822e2fe847d', '16ed132f5b88114f1d0bfd787c84c1f25d516f']
# Root: ../.git/objects/9a
# Directories: []
# Files: ['787600878cb463f0c8e05f0a7b55ef52ecc8bc', 'e58960132b8d1f6903b9c0de09febe4fc4ee43', 'd5bb3e17a49f2e5ec25289e858c4caa8319a84', '590bb693990d49679ba23bf21db2c23f405e7e', 'daa1509201b1f4eaba828316ce1c22767c2b22', '99898ac05f775d1aea3cf4d45fdb87dc80b7d4']
# Root: ../.git/objects/36
# Directories: []
# Files: ['a69026002a2c7633eab6827afff1330a573b0d']
# Root: ../.git/objects/5c
# Directories: []
# Files: ['a6efa0a1dced1cb2906dd5783f064d0a39f777', '2495a19239f159495dfa3e9c1e83c9520814db']
# Root: ../.git/objects/09
# Directories: []
# Files: ['28a954e267c06b8c6bcffecda2601a2e99014f', 'cd97defd2ba3a4f310cfe87aced8a1f1892f18']
# Root: ../.git/objects/31
# Directories: []
# Files: ['79410089f5d90e31e04f54696685199aaf21f9']
# Root: ../.git/objects/info
# Directories: []
# Files: []
# Root: ../.git/objects/91
# Directories: []
# Files: ['e0a4eaa68f593de82a15f8001a8513ae65a3c3', 'edc262472aeba3220260658cb7432bf708f745', '0fabd9e82367069afb859672a2d42456e08e86', '64204d06f93cf809932bf74c70e446264cb01f']
# Root: ../.git/objects/62
# Directories: []
# Files: ['1a8b9e36a3136f1d45b80ecfb4d3541d16b682', '289f50d111e9784a3097631fcfa17d303f0276']
# Root: ../.git/objects/3a
# Directories: []
# Files: ['7eea9e5fd2df57b0daf883efa23c16f0d84ce1']
# Root: ../.git/objects/54
# Directories: []
# Files: ['24b12d741859af469f597f4a9b94b0bf4bd5d2', 'b3f66314b160e75d1cded0baaec7321037347d', '4027b74967888eba497399c18df77bf25548ae', 'e8ba888329c6228932d2367aaba7b21faefc4f', '61d3a651ad986d1be20e66c074723bca80c5f4']
# Root: ../.git/objects/53
# Directories: []
# Files: ['1fd3a4e0c19b929f761fba666b565738935dce', 'b17bcbf3f644b1cc4a1815aa82f8706d782047', 'bf495a98b3ea02a600160f6bf548e6034c773f']
# Root: ../.git/objects/3f
# Directories: []
# Files: ['5f755d761876885d4372c5dfb2d2041e349afa', 'e1231b2a25d95087b9cba43165aab6c2e3428a']
# Root: ../.git/objects/30
# Directories: []
# Files: ['388cc041248e36b358c6819879dda41ceeebc0']
# Root: ../.git/objects/5b
# Directories: []
# Files: ['5a84e49dae5538b5eaa6c8e3d999dd1e128c98']
# Root: ../.git/objects/37
# Directories: []
# Files: ['fe9752aa4ff2b3923bc31eee4b1b7cd1570849']
# Root: ../.git/objects/6d
# Directories: []
# Files: ['e20e38468608bd724bdc3d147f5b5a4705ab50', 'ceaa893235f76e1ac12471d1a0d5a66e9d2afe', '51c12dfae3219e64b6d81c543fb81e3e9a8a19']
# Root: ../.git/objects/01
# Directories: []
# Files: ['6d924973c0d63c1ee446c43ad6fbd8d0c498aa', 'c41a7402e16c807729519f798f6b30bd950534']
# Root: ../.git/objects/06
# Directories: []
# Files: ['ea866803c8d63e5e889dac865654ee9b20c352', '2c1da9cd257a07baf91f84dd0583d170e8c257', '94b458c1b9bd6fd8ab6c6299de2b3814c3c4c2', '3fb89fd19dc87ca54c04c830d842e3b49a5f5a']
# Root: ../.git/objects/39
# Directories: []
# Files: ['929c074718c7549fff558fd35aeaaeb2cfecc0', '542a6b53621d44a9d33b84c05790ac24f14bff', '8e1ef9edd5569999a836e51f7feb16990b1d82']
# Root: ../.git/objects/99
# Directories: []
# Files: ['4b6f3e01e4601d0200e6d5ae7e5245dcef263d']
# Root: ../.git/objects/52
# Directories: []
# Files: ['d506073da6c8887d13fb5dd6bad0a8d26034bd', 'c66c41eece0a4bd5d2d299193e48b910c3cfd1']
# Root: ../.git/objects/55
# Directories: []
# Files: ['598cafc066db7f4948e66b24336217b00cdc9f', '31f734cf57c80cf9551c2f16275c4106dfcb50', '9de9d46ea1e139c96cfc74ce8bac6a48ee0c6a']
# Root: ../.git/objects/0f
# Directories: []
# Files: ['833c04da484f5371e679e8609735133e971f68', '0d5b18ee5f77ab46d8ad2f918f044d3202b5d8', '48f8a2e30811e85a00eb18a6cfe8947098bcaf', 'de29c0120f86400b9089a91be6775319ed3890']
# Root: ../.git/objects/0a
# Directories: []
# Files: ['b9e1df4b0ac0c2953cac8ac139e9aabdd6ddb3', '663c813dd6ace426ad2f28c0f412aa2ef8cf2d']
# Root: ../.git/objects/90
# Directories: []
# Files: ['872cc3f6d9190bf5215fe4c409fce54d8ebd42', 'c2ce8da27836f49e52f1cf78664ec7bf2b7de9']
# Root: ../.git/objects/bf
# Directories: []
# Files: ['f3a29cefb5caff5cc2c95dcbebb8cfa526b06f']
# Root: ../.git/objects/d3
# Directories: []
# Files: ['7117b33cf9c9e993bd9b9c1e3c945b91452330']
# Root: ../.git/objects/ba
# Directories: []
# Files: ['1e3a9642e65663af4b5523a1e31b69ca13e929', '83ecb4874549114ae6890c7c3c1204d3b2199b']
# Root: ../.git/objects/a0
# Directories: []
# Files: ['6b449b54d9e46d77c7d3b09102945b338bf749']
# Root: ../.git/objects/a7
# Directories: []
# Files: ['55a8e3e2bbefcd0a8f92bf79ec1cac19355039', '0814c2b1dc1a891be11398146e84c618854782', '9984c71f7f5db1f7670a9684e08e47e258e1b5']
# Root: ../.git/objects/b8
# Directories: []
# Files: ['a80565f43de4ad9f9940a18acbc0ea432f5593', 'ce2dcbf9879e26392056e4bbf7a0acf3c9bc1a']
# Root: ../.git/objects/b1
# Directories: []
# Files: ['e113dd1b8041c60539afe150266d117fd76348']
# Root: ../.git/objects/dd
# Directories: []
# Files: ['1bd24f1a0228d260732e03d07c93a41897da59']
# Root: ../.git/objects/dc
# Directories: []
# Files: ['050642aa7e34963d7ca3a6da4a514d47568866']
# Root: ../.git/objects/b6
# Directories: []
# Files: ['e6269e38a98cb233038171215f442a9c3a407e']
# Root: ../.git/objects/a9
# Directories: []
# Files: ['7582be7ed4663159ae0566207e2a9546b1b252']
# Root: ../.git/objects/d2
# Directories: []
# Files: ['88c47f04fc16c1394b0c68b4b3a87617e61ab3', '15a51b77435b9ad27589b101377a4098e7d2bb']
# Root: ../.git/objects/aa
# Directories: []
# Files: ['2f6a3cc259baa0a61d891db1fec9b751488391', '3918a27056641a9dd8fb146aacb4e6a170e231', '9678946e81a8ed13425405651c14598c541d00', '14e687309af8cdd43778e2b20b57be5116065e']
# Root: ../.git/objects/af
# Directories: []
# Files: ['1da1a461008821d812c4a0fd5d864ba7713d70']
# Root: ../.git/objects/b7
# Directories: []
# Files: ['a4e46a2833e2b4b122016a750a00d1370d715a', 'a4b56716cee8185c516ca882eb446bae77c553']
# Root: ../.git/objects/db
# Directories: []
# Files: ['499bc48f1c5ea6340d0d444290a22c35e19c36', '4957c02ce7f137e348f475fad3af6834c45b83']
# Root: ../.git/objects/a8
# Directories: []
# Files: ['9975723faf45e60bee2d6a89c3d8463499d9c3', '842210b1a443de9110a7b33bab6870b8987f61']
# Root: ../.git/objects/de
# Directories: []
# Files: ['9ea69dc9dd7c62881fb46e191f3488e1f2ef8e', 'db5a7f816a37b88151c8e23fed0624683a536d']
# Root: ../.git/objects/b0
# Directories: []
# Files: ['ac28da9a36e7a40dffc7a381bd6560beeac49b', '0fff8ff6ce361b2177bf3aad96dfb7cac45490']
# Root: ../.git/objects/a6
# Directories: []
# Files: ['0bb41386750288227af5de699486e170ffe8bf', 'e5d87f27f621f70fae989badbe36dee873968d', '2171af5fade96e0d54ecfa5d8922611312d6bf']
# Root: ../.git/objects/b9
# Directories: []
# Files: ['2ef5d97a6e00bc95d7642b813ac70b0b2663a8']
# Root: ../.git/objects/ef
# Directories: []
# Files: ['6ba48b17146be61a06998a26faa165bd391c42', 'dd61d6a063f8697db7aadfc78228d9c7305dad', '45b8317713ad0af403db4074607fb5f300598a']
# Root: ../.git/objects/c4
# Directories: []
# Files: ['ff0cb673f9ee0f029cce052e17416131314c9d']
# Root: ../.git/objects/ea
# Directories: []
# Files: ['ab198635374db498b0ebe392bbfe52505a2ff4', '4682d0db8aa02fdf0ee07c66fcd707a8a334e7']
# Root: ../.git/objects/e1
# Directories: []
# Files: ['2f6aee0ae05edce25abc0dab55e5b63e85f6ee']
# Root: ../.git/objects/cd
# Directories: []
# Files: ['a4d71aefc8bac00ee69a13b2fe819d5f142955', 'be6b1b9155a40942d88a2eee0e382d417df095']
# Root: ../.git/objects/cc
# Directories: []
# Files: ['bdbcda38b91122089fcf4560ee32c98fac8576']
# Root: ../.git/objects/e6
# Directories: []
# Files: ['5b79f9b166a03f92c476c3af874e0e81cddc4b', 'f2bf5c695ab2a50dfb85d36a3b76e00afb5d54', 'f4883f14cfa8ee7bed125724a63487e3442d35']
# Root: ../.git/objects/f9
# Directories: []
# Files: ['359f47bad7140d23fdb3037a72af91c345c9a0', '6dd953dfa994dbdf5b0fa250596e55f4313b26', '9077c8636c3e97aeda329eb25cea27d7aab12f', '5b7ae53d2572be0a8fa00e430ab9fc546630b1']
# Root: ../.git/objects/f0
# Directories: []
# Files: ['7eb1fcb58edc034eea433ccece39049f777cee', 'dcd996fc577150a60289245b375a9e91e70cf8']
# Root: ../.git/objects/f7
# Directories: []
# Files: ['9c4f4302eb0debf8668abbd14a6a8509b5e878', '040e2bf1ff9b7c69b35274709ad88983162dc8']
# Root: ../.git/objects/e8
# Directories: []
# Files: ['c84efe781942b746794b0c8aa203ad52ead64a', '1c83fd89f0928375d18995edda4c5bdedfb8fb']
# Root: ../.git/objects/fa
# Directories: []
# Files: ['5c2464dc859cfca02838a302667d9390727b2f']
# Root: ../.git/objects/ff
# Directories: []
# Files: ['38a7de80ef158ec3edd3c4d540b0e3b0ff8222']
# Root: ../.git/objects/c5
# Directories: []
# Files: ['e7a3c4bdf1fc4dd7be9e1f136708864373356a', 'f4a4a8100e98e670201907ffc8a0c3e721a82b']
# Root: ../.git/objects/c2
# Directories: []
# Files: ['6c856865dc2dc87678a2deb42f3c1faca0eddf', '12ee7378be20bd349afe4b749f5e0e6ae78a93', '63842ce6a6fa6b214f976469e330d67cca60f5']
# Root: ../.git/objects/f6
# Directories: []
# Files: ['f290a22c769089f085414fcb0b1264527df2a8', 'ff64ba32b748574f99732cd1c10bbec469e5bd']
# Root: ../.git/objects/e9
# Directories: []
# Files: ['e9f33f39af78ef48811de23c9595852a810775', 'bbff7d6dcc98b57bd6436d1247b8a422ff7667']
# Root: ../.git/objects/e7
# Directories: []
# Files: ['c8f35c5bb7345f03ecac76316db6f2951376c0', '55ac434dd3baa3d5950490b3226915c56b5b04', '45c17eadaf9600082ad9e957a67eb3b98f8650']
# Root: ../.git/objects/cb
# Directories: []
# Files: ['1ef55147456c7c72474a9b076855d9932f6ad2', '8fb296f2c2eb211b60a849745cabd4e1d10c7e', '4013fb89fa20e3ed6276c79d5832ddc7414695']
# Root: ../.git/objects/f8
# Directories: []
# Files: ['874c0b7e22625070e12e73524e416dd098f3fc', '094e95e6306c738c29f542e6ee407e75b178e7']
# Root: ../.git/objects/ce
# Directories: []
# Files: ['59af51cc999803195f73b4f41e36c139ee4ca8', '122ec02be28c9727bdd58ca7adf8f7ec6cfae8']
# Root: ../.git/objects/e0
# Directories: []
# Files: ['7230729076a92eb42b13ca092e05a5d48d94f4', '74c5f6bb8b0e518cb8d293f14a58949ad0c26c', 'bdd81face06a0f5339464f0313ad37eb4ecd9f']
# Root: ../.git/objects/46
# Directories: []
# Files: ['4e975973b5af507524796bdb72e3551354e1fa', '6d95966225a8c8ef58e55844d0167cfccb35a6']
# Root: ../.git/objects/2c
# Directories: []
# Files: ['5ee593e94fec3bbbc6264a00d576a7db84ae8b', 'a7109331b6c0eb30053fa210ec70f1d568715d']
# Root: ../.git/objects/79
# Directories: []
# Files: ['7493ff76bb29cefb394722305b8c8d0753fa94', '425d8e6dd503c63f3489d8702d7e4cbc00c036', '4cabc1fd419a27aeb2ac58d37ecfd66ece6413', '4d3e0247ed300df5ce9d40df6132658f54e0b2']
# Root: ../.git/objects/2d
# Directories: []
# Files: ['b4fa737e6c5e1a78a4f4fe19926a100b9844be', '716b1fa6d14b63e4b0394fbb83b499e47d50ed', '8c07bdeeda8c452fe2e9053eb181a3c15bc665', 'd10b42aa18918bb3f850899d88970512b5b79e']
# Root: ../.git/objects/41
# Directories: []
# Files: ['f4fcdae52717fefcc37343c9fb4cc11f4ec9c9']
# Root: ../.git/objects/83
# Directories: []
# Files: ['84728c695bd538c3d852d43207e3d0bfd7ef3d']
# Root: ../.git/objects/1b
# Directories: []
# Files: ['4ead3f341fd5846337dc53fca6984719273862', '9240949ef935ab2edd48fcf49cf4d1ae72e850']
# Root: ../.git/objects/77
# Directories: []
# Files: ['90486437563a1083870e1f3f4bfbee5e32b9f1', '88b20bfd805eb72bf40c746a407c2ac0e5790b', '0f74a13255b208049f289f5d1f16ce0dc4f127']
# Root: ../.git/objects/70
# Directories: []
# Files: ['149fc9d3ca56e76c36427070c08ccff7af7cc8', 'fe35a988fd1e024cb76ccbb8dfab78fbfa4a9c', 'b62fb3ec6ad3fb462fbef3403f05f8711848be', '153469fbbccc268dc19026f08bef48df9e1987', '5bc6fb957a02b2885f5d3bf9c464e4c47fecb2']
# Root: ../.git/objects/24
# Directories: []
# Files: ['f03e1f544919f1b191b7a0914fb8834eca7523']
# Root: ../.git/objects/4f
# Directories: []
# Files: ['9d079a8c05d943395d22d577b3b084a4a54ea1', '424c4dc7e162d7108c38bb5869dc4d87e1b6f9']
# Root: ../.git/objects/8d
# Directories: []
# Files: ['9f138eb2048f1d3fc57df12a6bbb6f84bd86be']
# Root: ../.git/objects/15
# Directories: []
# Files: ['a67795e678c3b0cea65c5c3b3ede230a3d51ee', '8aba8fd1de418761ef232b0191ea604f694ca3', 'ef6862728a4a4edcd616fcca79122f895ceace']
# Root: ../.git/objects/12
# Directories: []
# Files: ['3304e0be446cefce0f29cc47ac636dea86f53d', 'ebd3ad134868512e522613d0b44958ef112fac', '74072d19f5a3fe03763ac4daa468805f05cd29']
# Root: ../.git/objects/8c
# Directories: []
# Files: ['e1467dca38ee50eb4318b3ff45d699683f280f', 'ed8ab2412eb5ed6f5eb5e79954014ee913e2c0']
# Root: ../.git/objects/85
# Directories: []
# Files: ['38dd1dc763a8d9e77063acf9a61559553dd51e', 'f95eddc3f4a71aec8c40bf6e6651a08ae31723', '954eabcfc32c9ef6765ae90ef192256664874e']
# Root: ../.git/objects/1d
# Directories: []
# Files: ['bc48834d92e93c3e70bb80e9eafb2fbe6a58a6', '8584da908f464b5ea8162aa7e6d52dc9db49e8', '81ee06dea29730ff641158d516e2bf68fdc7dc']
# Root: ../.git/objects/71
# Directories: []
# Files: ['ba260ce30bfca11032570fc397745df9292b7d', '1906991aa1fdf9eb49cfa0e016c05e93b6790b', '226a5bb08f0b1fe0bc290618c6c21de6c6aa6e', '7eff206fd0428fcd1133253f1fdfada62cc09c']
# Root: ../.git/objects/76
# Directories: []
# Files: ['210a2f99558b59d25fa57acbd2282d07d62f44']
# Root: ../.git/objects/1c
# Directories: []
# Files: ['4b97e22710d4b7c20dc423d331efce543f56f2']
# Root: ../.git/objects/82
# Directories: []
# Files: ['161b2d77c9a66bf3a80a1fc39f555350561e95', 'ac0f93221ee3c36b5ab3c24505c0b316c49f5d']
# Root: ../.git/objects/49
# Directories: []
# Files: ['bea6ae12fc7337d84c4de87993844e43a102af', 'ba64e3cf5ec3eb16c62316b242dcf355059f5b']
# Root: ../.git/objects/40
# Directories: []
# Files: ['84faa712e2abccec972a9266cdbe68f1f4e060', '4f1130fdd97d25e5ad6da9139a19a1a694a721']
# Root: ../.git/objects/2e
# Directories: []
# Files: ['fece5395f14dd5308fc02313833ead0d995c9c', '133bd80a7b44c0e469d91ba1a2c6cee23b4864', '1a411ae13e8005dc6dc8bd06734e57c39f9f3a', '787867b1144a74b2d802d13b077693e09f8b62']
# Root: ../.git/objects/47
# Directories: []
# Files: ['2a358fe91b8cef3484893b2269461ad49c8929', '8e34dcdcb9be7cf30d153d198131e7fdb88019', 'd1373d60af93958f4b73777da93440631d7ef3']
# Root: ../.git/objects/78
# Directories: []
# Files: ['bc99de7fc401626a09083951e06f977dda84a1', '4f3fda555e65b7d0d428476fd0c051bc6732f1', '5bed7662f3d6cfa40582fbf8b240c1a726be8e', '2dac3f5b44089d9b801aa1d5f45a9594a71abd', '3d05928c4109931b2a72257db78e7528d9f1ef', 'cc2b9b838434b03212e7cab4e24d61629c4ba3', 'ecc3216c6d5fa0de434b0208b3f726ad1fb267']
# Root: ../.git/objects/8b
# Directories: []
# Files: ['8a4e784f109f561c21929956dcaf1cb32dfd13', 'c2378fbb0923b9e0f748dabab8e18aa4e22446']
# Root: ../.git/objects/13
# Directories: []
# Files: ['f5dde36492c61635a144bd619814ba4f2dca4c']
# Root: ../.git/objects/7f
# Directories: []
# Files: ['7f7070673857d7c1325c6ad47fc50224bad00c', '5abdc89b050407cadad46fa3574e15d58dd5a4']
# Root: ../.git/objects/7a
# Directories: []
# Files: ['e7f6cbe902f0230bd8dd63eb967a39d7c75f43']
# Root: ../.git/objects/8e
# Directories: []
# Files: ['95aebca5e92ea0fadfdde6a59a7f3dc648cda5']
# Root: ../.git/objects/22
# Directories: []
# Files: ['7315e08a86c21ab5c7732d39482119ad9804d1']
# Root: ../.git/objects/25
# Directories: []
# Files: ['0fd5d84980904ee7494a2ceddd34ebb02450aa', 'bc50b6356a894b144b485f9780d9720f4438f1']
# Root: ../.git/info
# Directories: []
# Files: ['exclude']
# Root: ../.git/logs
# Directories: ['refs']
# Files: ['HEAD']
# Root: ../.git/logs/refs
# Directories: ['heads', 'remotes']
# Files: ['stash']
# Root: ../.git/logs/refs/heads
# Directories: []
# Files: ['main']
# Root: ../.git/logs/refs/remotes
# Directories: ['origin']
# Files: []
# Root: ../.git/logs/refs/remotes/origin
# Directories: []
# Files: ['HEAD', 'main']
# Root: ../.git/hooks
# Directories: []
# Files: ['commit-msg.sample', 'pre-rebase.sample', 'pre-commit.sample', 'applypatch-msg.sample', 'fsmonitor-watchman.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'post-update.sample', 'pre-merge-commit.sample', 'pre-applypatch.sample', 'pre-push.sample', 'update.sample', 'push-to-checkout.sample']
# Root: ../.git/refs
# Directories: ['heads', 'tags', 'remotes']
# Files: ['stash']
# Root: ../.git/refs/heads
# Directories: []
# Files: ['main']
# Root: ../.git/refs/tags
# Directories: []
# Files: []
# Root: ../.git/refs/remotes
# Directories: ['origin']
# Files: []
# Root: ../.git/refs/remotes/origin
# Directories: []
# Files: ['HEAD', 'main']
# Root: ../data
# Directories: []
# Files: ['HeightWeight.csv', '.DS_Store', 'Car Electronics.csv', '03_city_edmonton_assessment_small.csv', 'sportsref_download.xlsx', 'Salary_Survey.csv', 'threads_reviews.csv', 'train.csv', '03_city_edmonton_assessment_sample.csv', 'chipotle.tsv', 'cars.csv', 'titanic_train.csv', 'spam.csv']
# Root: ../workbooks
# Directories: ['file_list', '__pycache__', 'zz_OLD']
# Files: ['002_conditional_statements_sol.ipynb', '021_big_review.ipynb', '001a_python_example.py', '010_class_comments.ipynb', '011_looping_2_data.ipynb', '001_programming_basics_sol.ipynb', '017a_cards_sol.ipynb', '020_string_processing_regex_sol.ipynb', '025_refactor_cards_gui.ipynb', '005_file_access.ipynb', '007_other_data_structures_full_sol.ipynb', '018_cards_part_2.ipynb', '019_cards_3_import.ipynb', '017_inheritance.ipynb', 'cards_sol_1.py', '006_objects.ipynb', '012_algorithm_design_sol.ipynb', '017_inheritance_sol.ipynb', '002_conditional_statements.ipynb', '004_functions_sol.ipynb', '003_loops_sol.ipynb', '023_search_sort.ipynb', '005a_File_Loading_example_from_stats.ipynb', '004_functions.ipynb', '009_strings_sol.ipynb', '016_file_management_2.ipynb', '024_cards_ipython.ipynb', '018_cards_part_2_sol.ipynb', '013_arrays_and_numpy_sol.ipynb', '009_strings.ipynb', '011_looping_2_data_sol.ipynb', '025_refactor_cards_gui_sol.ipynb', '014_map_apply.ipynb', '022_abstract_multip_inh.ipynb', '014_map_apply_sol.ipynb', '006_objects_sol.ipynb', 'fib.csv', '017_args_kwargs.ipynb', '023_search_sort_sol.ipynb', '018_cards_part_2_akeem_in_class.ipynb', 'file_list.zip', 'helper.py', '012_algorithm_design.ipynb', '020_string_processing_regex.ipynb', '024_cards_ipython_sol.ipynb', '022_abstract_multip_inh_sol.ipynb', 'cards_sol_2.py', '013_arrays_and_numpy.ipynb', '016_file_management_2_sol.ipynb', '000_Setup.ipynb', 'chipotle.tsv', '015_overloading_sol.ipynb', '019_cards_3_import_sol.ipynb', '001_programming_basics.ipynb', '008_recursion_sol.ipynb', '017_args_kwargs_sol.ipynb', '007_other_data_structures.ipynb', '003_loops.ipynb', 'cards_sol_3.py', '017a_cards.ipynb', '005_file_access_sol.ipynb', '015_overloading.ipynb', '008_recursion.ipynb']
# Root: ../workbooks/file_list
# Directories: []
# Files: ['002_conditional_statements_sol.ipynb', '021_big_review.ipynb', '001a_python_example.py', '010_class_comments.ipynb', '011_looping_2_data.ipynb']
# Root: ../workbooks/__pycache__
# Directories: []
# Files: ['helper.cpython-310.pyc']
# Root: ../workbooks/zz_OLD
# Directories: ['file_list', 'development_working_dir']
# Files: ['fib.csv', 'file_list.zip', 'dl_process.ipynb', 'difference.csv', 'diffs.csv']
# Root: ../workbooks/zz_OLD/file_list
# Directories: []
# Files: ['002_conditional_statements_sol.ipynb', '021_big_review.ipynb', '001a_python_example.py', '010_class_comments.ipynb', '011_looping_2_data.ipynb', '005_file_access.ipynb']
# Root: ../workbooks/zz_OLD/development_working_dir
# Directories: ['file_list']
# Files: ['010_class_comments.ipynb', 'Clothing.csv', '017a_cards_sol.ipynb', '020_string_processing_regex_sol.ipynb', '005_file_access.ipynb', '006_objects.ipynb', 'residential.csv', 'Cycling.csv', '002_conditional_statements.ipynb', 'z00_classes.ipynb', 'overloading_sol.ipynb', 'cards_sol.py', '005a_File_Loading_example_from_stats.ipynb', '004_functions.ipynb', '009_strings_sol.ipynb', 'cards_3_import_sol.ipynb', '024_cards_ipython.ipynb', '018_cards_part_2_sol.ipynb', 'abstract_class.ipynb', '013_arrays_and_numpy_sol.ipynb', 'run_from_command.py', '021_big_review_sol.ipynb', 'inheritance.ipynb', 'poker_gui.ipynb', '011_looping_2_data_sol.ipynb', '025_refactor_cards_gui_sol.ipynb', 'car.ipynb', '014_map_apply_sol.ipynb', 'Strength Training.csv', 'file_list.zip', 'helper.py', '012_algorithm_design.ipynb', 'date_data_sol.ipynb', 'multip_inh.ipynb', '022_abstract_multip_inh_sol.ipynb', 'cards_sol_2.py', 'residential2.csv', 'difference.csv', '016_file_management_2_sol.ipynb', '000_Setup.ipynb', '001a_python.py', '023_functional.ipynb', 'diffs.csv', 'tmp.ipynb', 'car_inh.py', '001_programming_basics.ipynb', 'arrays_and_numpy_sol.ipynb', 'search_sort.ipynb', 'string_processing.ipynb', '017_args_kwargs_sol.ipynb', '007_other_data_structures.ipynb', '003_loops.ipynb', 'cards_sol_3.py', '008_recursion.ipynb']
# Root: ../workbooks/zz_OLD/development_working_dir/file_list
# Directories: []
# Files: ['Clothing.csv']

# %%
for root, directories, files, in moonwalker:
    print(f"Root: {root}")
    print(f"Directories: {directories}")
    print(f"Files: {files}")
# Out:
# Root: ../supplementary_practice_workbooks/moodle_exercises
# Directories: []
# Files: ['2_Examples.ipynb', '4_Day_1.ipynb', '1_racing cars.ipynb', '1_exapmles.ipynb', '2_Day_1.ipynb', '11_Inheritance_.ipynb', '6 Day 1 - Lists and Functions.ipynb', '2_More Exercises.ipynb', 'Week_9_Day_Sets_and_Dictionaries.ipynb', '10_Day_1_Object_Oriented_Programming.ipynb', '7_Day_1_Files_and_exceptions.ipynb', '3 Day 1.ipynb']
# Root: ../supplementary_practice_workbooks
# Directories: ['moodle_exercises']
# Files: ['Lecture23_24_workbook.ipynb', 'Lecture22_Regression_Tuning.ipynb', 'Lecture18_beginning_classification_part_2.ipynb', 'Lecture_09_10_Workbook.ipynb', 'Lecture05_conditions_loops.ipynb', 'Lecture21_Multiple_Regression.ipynb', 'Lecture20_pipeline_part_2.ipynb', 'Lecture15_beginning_regression_part_1.ipynb', 'Lecture02_basics.ipynb', 'Lecture13-14_Intro_ML.ipynb', 'Lecture21_22_workbook.ipynb', 'Lecture16_beginning_regression_part_2.ipynb', 'Lecture12_probability.ipynb', 'Lecture07-08_Pandas.ipynb', 'Lecture15-16_workbook.ipynb', 'Lecture09_data_wrangling_pandas_I.ipynb', 'Lecture11_descriptive_statistics.ipynb', 'Lecture05_workbook.ipynb', 'Lecture07-08_workbook.ipynb', 'Lecture02_workbook.ipynb', 'Lecture10_data_wrangling_pandas_II.ipynb', 'Lecture06_numpy.ipynb', 'Lecture03_workbook.ipynb', 'Lecture04_arrays_files.ipynb', 'Lecture04_workbook.ipynb', 'Lecture06_workbook.ipynb', 'Lecture13_workbook.ipynb', 'Lecture19_pipeline_impute_part_1.ipynb', 'Lecture23-24_classification_methods.ipynb', 'Lecture17_beginning_classification_part_1.ipynb', 'Lecture14_workbook.ipynb', 'Lecture03_datatypes.ipynb', 'data_dictionary.ipynb', 'Lecture11_12_Workbook.ipynb', 'Lecture19_20_workbook.ipynb', 'Lecture17_18_Workbook.ipynb']
# Root: ../reference_material/docs_and_guides
# Directories: []
# Files: ['jupyter_markdown.pdf', 'small_python_cheat_sheet.pdf', 'data_eng.pdf', 'Super_Inherit.pdf', 'python_decorators.pdf', 'pythonlearn.pdf', 'large_python_cheat_sheet.pdf', 'Intro_to_Machine_Learning_in_Python.pdf', '20_python_concepts.pdf']
# Root: ../reference_material/slides/zz_OLD/Repository
# Directories: []
# Files: ['Lecture06_numpy.pptx', 'Lecture01_Introduction.pptx', 'Lecture16_LEAST_ ANGLE_REGRESSION.pdf', 'Lecture13_Intro_ML.pptx', '016_Pipelines.pptx', 'Lecture02_python_intro.pptx', '014_Forest_Ensamble.pptx', 'Lecture04_arrays_files.pptx', '008_Error_Bias_Variance.pptx', 'Lecture07-08_Pandas.pptx', 'Lecture21-22_Para_Tuning.pptx', 'Lecture14_ml_basics.pptx', 'Lecture17-18_Classification.pptx', '008_Classification_Log_Reg.pptx', '004_ml_basics.pptx', 'Lecture19_Pipelines.pptx', '018_Gridsearch.pptx', 'Lecture23-24_Classification_Tuning.ppt', '002_Intro Machine Learning.pptx', '010_log_reg_2_imbalanced.pptx', '012_Trees.pptx', 'Lecture05_conditions_loops.pptx', 'Lecture03_datatypes.pptx', '006_Linear_Least_Squares.pptx', 'Lecture15-16_Regression.pptx']
# Root: ../reference_material/slides/zz_OLD/Used
# Directories: []
# Files: ['015_log_reg.pptx', '013_categorical_features.pptx', '007_arrays.pptx', '022_Feature_Selection.pptx', '008_review_1.pptx', '005_Pandas_Datasheet.pptx', '009_Correlation_Scatter.pptx', '006_Basic_Descriptive_Stats.pptx', '014_pipelines.pptx', '012_median_and_scaling.pptx', '003_loops.pptx', '023_Basis_and_Regularization.pptx', '002_vars_and_control.pptx', '018_regression_review_stats.pptx', '017_Gridsearch.pptx', '011_Linear_Least_Squares.pptx', '021_Forest_Ensamble.pptx', '004_functions.pptx', '016_log_reg_2.pptx', '021_regression_tree.pptx', '020_unsupervised_cluster.pptx', '010_Errors.pptx', '019_Trees_over_under.pptx', '020_Trees_2_Regularization.pptx']
# Root: ../reference_material/slides/zz_OLD
# Directories: ['Repository', 'Used']
# Files: ['.DS_Store']
# Root: ../reference_material/slides
# Directories: ['zz_OLD']
# Files: ['006_classes_obj_1.pptx', '023_asn2_work_time.pptx', '.DS_Store', '001_intro_setup.pptx', '~$006_classes_obj_1.pptx', 'inheritance.pptx', '019_test_driven.pptx', 'os_system.pptx', '003_loops.pptx', '025_UI.pptx', '002_vars_and_control.pptx', '008_recursion.pptx', '021_review_verification.pptx', '012_algo_interface_errors.pptx', '007_other_data_structures.pptx', '020_regular_expressions.pptx', '005_file_access.pptx', '018_cards_2.pptx', '017_arg_kwarg.pptx', '004_functions.pptx', '013_arrays.pptx', '014_bulk_actions.pptx', '026_refactor.pptx', '009_comments_enum.pptx', '015_overload.pptx', '~$005_file_access.pptx', '024_search_sort.pptx', '022_mult_inh_abc.pptx']
# Root: ../reference_material
# Directories: ['docs_and_guides', 'slides']
# Files: ['.DS_Store']
# Root: ../images
# Directories: []
# Files: ['enumeration.png', 'repr.png', 'inheritance.png', 'make_dict.jpg', 'array_calendar.png', 'theon.jpeg', 'map.webp', 'binary_linear_search.gif', 'paths.png', 'python-multiple-inheritance.png', 'marvin.png', 'walk.gif', 'multilevel_inheritance.png', 'formatting.png', 'inh_types.webp', 'regex.png', 'series_dataframe.png', 'fact_breakdown.png', 'nested_for.png', 'sorting-algorithm.gif', 'abc_collections.png', 'stump.png', 'weak_learn.png', 'pandas.png', 'logic-gates.webp', 'for_loop.jpg', 'while_loop.png', 'for_loop.png', 'encapsulation.jpg', 'if_else.png', 'array_memory.png', 'map.png', 'sorting.png', 'array.png', 'df.webp', 'list_comprehension.png', 'multiple_inh.png', 'files_os.png', 'harvard_grades.webp', 'early_stopping.png', 'example_dropdown.png', 'inheritance_types.jpg', 'histogram.png', 'regex_cheatsheet.webp', 'algorithm.jpg', 'set_operations.png', 'numpy_indexing.png', 'nested_if.png', 'map_inputs.png', 'new_method.png', 'arg_kwarg.png', 'string_index.png', 'lambda.png', 'hash-table.png', 'markdown.webp', 'file_permissions.png', 'python-sets.jpg', 'factorial.png', 'array_reshape.jpeg', 'binary_vs_linear.jpg', '3d_array.webp', 'try_except.png', 'hierarchial_inheritance.png', 'seek.webp', 'multilevel_inheritance.webp', 'iterator.png', 'var_scope.webp', 'dict_list.png', 'recursion.png', 'dict_list.jpg']
# Root: ../course_material/labs/lab1/github/test
# Directories: []
# Files: ['test_csv_load.py']
# Root: ../course_material/labs/lab1/github/workflows
# Directories: []
# Files: ['classroom.yml', 'copy_template_files.yml']
# Root: ../course_material/labs/lab1/github
# Directories: ['test', 'workflows']
# Files: ['test_file2.txt', 'test_file1.txt']
# Root: ../course_material/labs/lab1
# Directories: ['github']
# Files: ['SAMP_SOL_Lab_1_test_generator.py', 'requirements.txt', 'test_harness.py', 'generate_tests.ipynb', 'README.md', 'START_Lab_1.py', 'SAMP_SOL_Lab_1.py', 'SAMP_SOL_Lab_1.ipynb', 'SAMP_SOL_responses.csv']
# Root: ../course_material/labs/lab6/github
# Directories: []
# Files: ['classroom.yml', 'test_START_Lab_2.py']
# Root: ../course_material/labs/lab6
# Directories: ['github']
# Files: ['requirements.txt', 'SAMP_SOL_Lab_6.py', 'SAMP_SOL_Lab_6.ipynb', 'Lab_6_Q_5.py']
# Root: ../course_material/labs/lab0/github/test
# Directories: []
# Files: ['test_csv_load.py']
# Root: ../course_material/labs/lab0/github/workflows
# Directories: []
# Files: ['classroom.yml', 'copy_template_files.yml']
# Root: ../course_material/labs/lab0/github
# Directories: ['test', 'workflows']
# Files: ['.DS_Store']
# Root: ../course_material/labs/lab0
# Directories: ['github']
# Files: ['requirements.txt', 'test_harness.py', 'SAMP_SOL_Lab_0.py', 'README.md', 'START_Lab_0.py']
# Root: ../course_material/labs/lab5/github
# Directories: []
# Files: ['classroom.yml', 'test_START_Lab_2.py']
# Root: ../course_material/labs/lab5
# Directories: ['github']
# Files: ['requirements.txt', 'Lab5_input.txt', 'SAMP_SOL_Lab_5.py', 'SAMP_SOL_Lab_5.ipynb']
# Root: ../course_material/labs/lab2/__pycache__
# Directories: []
# Files: ['SAMP_SOL_Lab_2.cpython-310.pyc', 'START_Lab_2.cpython-310.pyc']
# Root: ../course_material/labs/lab2/github
# Directories: []
# Files: ['classroom.yml', 'test_START_Lab_2.py']
# Root: ../course_material/labs/lab2
# Directories: ['__pycache__', 'github']
# Files: ['requirements.txt', 'test_harness.py', 'SAMP_SOL_Lab_2.py', 'START_Lab_2.py', 'SAMP_SOL_Lab_2_test_generator.py', 'SAMP_SOL_Lab_2.ipynb', 'SAMP_SOL_responses.csv']
# Root: ../course_material/labs/lab3/__pycache__
# Directories: []
# Files: ['START_Lab_3.cpython-310.pyc']
# Root: ../course_material/labs/lab3/github
# Directories: []
# Files: ['classroom.yml']
# Root: ../course_material/labs/lab3
# Directories: ['__pycache__', 'github']
# Files: ['requirements.txt', 'test_harness.py', 'START_Lab_3.py', 'SAMP_SOL_Lab_3.py', 'SAMP_SOL_Lab_3.ipynb']
# Root: ../course_material/labs/lab4/github
# Directories: []
# Files: ['classroom.yml', 'test_START_Lab_2.py']
# Root: ../course_material/labs/lab4
# Directories: ['github']
# Files: ['requirements.txt', 'test_SAMP_SOL_Lab_4.py', 'SAMP_SOL_Lab_4.py', 'START_Lab_4.py', 'SAMP_SOL_Lab_4.ipynb']
# Root: ../course_material/labs
# Directories: ['lab1', 'lab6', 'lab0', 'lab5', 'lab2', 'lab3', 'lab4']
# Files: ['.DS_Store', 'test.csv', 'output.csv', 'inputs.csv', 'output2.csv']
# Root: ../course_material/assignments/asn1/data
# Directories: []
# Files: ['Car Electronics.csv', 'Strength Training.csv']
# Root: ../course_material/assignments/asn1
# Directories: ['data']
# Files: ['requirements.txt', 'asn_1.py', 'START_Asn_1.ipynb', 'README.md', 'START_asn_1.py', 'Asn_1_1241.ipynb', 'Assignment_1_sample_sol.ipynb']
# Root: ../course_material/assignments/asn2/data
# Directories: []
# Files: ['output.csv', 'inputs.csv']
# Root: ../course_material/assignments/asn2
# Directories: ['data']
# Files: ['START_Asn_2.ipynb', 'requirements.txt', 'input_output.png', 'README.md', 'example_results.png']
# Root: ../course_material/assignments
# Directories: ['asn1', 'asn2']
# Files: ['.DS_Store']
# Root: ../course_material/exams/exam_3
# Directories: []
# Files: []
# Root: ../course_material/exams/exam_2
# Directories: []
# Files: []
# Root: ../course_material/exams/exam_1/applied
# Directories: []
# Files: ['test_harness.py', 'exam_1.py']
# Root: ../course_material/exams/exam_1/written
# Directories: []
# Files: []
# Root: ../course_material/exams/exam_1
# Directories: ['applied', 'written']
# Files: []
# Root: ../course_material/exams
# Directories: ['exam_3', 'exam_2', 'exam_1']
# Files: []
# Root: ../course_material/documents
# Directories: []
# Files: []
# Root: ../course_material
# Directories: ['labs', 'assignments', 'exams', 'documents']
# Files: ['.DS_Store', 'syllabus_1241.docx', 'syllabus_1231.docx']
# Root: ../.git/objects/61
# Directories: []
# Files: ['e659c266b2b319e7b1f899a99d2fb2ee6dcf86', 'ac6f5d0879f456f5abb49b9f3dbd242f2107f7', '4f285270b40090e5870d3a03e15a78e022906c', 'dead95e3c724af49338fa0ed5d0f528374e6f2']
# Root: ../.git/objects/0d
# Directories: []
# Files: ['c138c437efb97d48583d0cce81c2d94d6a8d7a', 'c80adf56277d95330cd8e6ae4503db00b08be5']
# Root: ../.git/objects/59
# Directories: []
# Files: ['5c23fa45daf7cf09b1ae6cfb12cf22c16bbb6a']
# Root: ../.git/objects/92
# Directories: []
# Files: ['4b1b1fef07076d331c45e296b930fac32e0a2a']
# Root: ../.git/objects/0c
# Directories: []
# Files: ['0edd0464b02e8cec3efe92674191d25d8b2aa1', '9cd4f3a31838b798f93944d1201f5abed83623']
# Root: ../.git/objects/66
# Directories: []
# Files: ['fabafdc4198a5f37f84e22c769cc3430f64672', '94f6ac50e590fb5623fefca255a840bc901541', '05769a8357287377023d5057ab182e867bb5f3']
# Root: ../.git/objects/3e
# Directories: []
# Files: ['87c671586eeaa81849667fc052b94f4bc6b9a6']
# Root: ../.git/objects/68
# Directories: []
# Files: ['3714dee73fa918632dc1c4239987cecb9075bb']
# Root: ../.git/objects/57
# Directories: []
# Files: ['08ad17e91fd4c60d4d45452ad447ceb5a89fa8']
# Root: ../.git/objects/3b
# Directories: []
# Files: ['df2514c9afd4786d0a3dad3db10af74e9cb4d1', '2d42e5ddca074660220a68e1aa4ee24c3cae9b', '52a7ec1f3017f6c1b16883a2a84dada8e22a56', 'a7d9507067098f87cd174273997de164ef6f2d']
# Root: ../.git/objects/03
# Directories: []
# Files: ['4d1c994d3a3434b45995f5938a3387f87c2a7d', '01062ed90617e5a1206b9b27bc4ee8a33053ff', '17859af3e2255343e70ada094a72711660e09a']
# Root: ../.git/objects/9b
# Directories: []
# Files: ['04d8eff15eb2085e1f5dae6f7ddce9ce84d3a4']
# Root: ../.git/objects/9e
# Directories: []
# Files: ['69ccce9a276a835f112f5c894022cd4b583b9e', 'e13d57d00cc70610cfd5f652138047d931d755', 'c10bab19be936d48dc226f2e79033a2578dd39', '8857bc9fe3e17aa125b0da4f7dcfbc091824b7']
# Root: ../.git/objects/04
# Directories: []
# Files: ['e94a56eb896e0badec29d0f4220383b178e19b', 'fcb300ad8f1d69611ab74ec9e45c670872fd51', '9c520c7359742a0ab5b13f2e4fea844aeadd57']
# Root: ../.git/objects/6a
# Directories: []
# Files: ['59505a19225fda929aa133550cb19ba3042f83', '9671884e19961c7f81997680bb86410563fce9', 'b6f7fe6b3d4d38caacd20b3c723d27ce17804a']
# Root: ../.git/objects/32
# Directories: []
# Files: ['8e0089b13192a4f029f01e892fb0e0312cab77']
# Root: ../.git/objects/35
# Directories: []
# Files: ['7f14301be59ece47ab6ff8a89984a6165adf27']
# Root: ../.git/objects/69
# Directories: []
# Files: ['0903887cac2b03279360617418c866c69d95e8', '106f2691eacb52bd9e2d22f0fd57fb2c1e6fba']
# Root: ../.git/objects/3c
# Directories: []
# Files: ['0c8d7fc4dd3dec723ad6ff49668a12255bdebe']
# Root: ../.git/objects/56
# Directories: []
# Files: ['b63687cb158fb79899ce24be9cb8ac0b9f7f54', '65ca9402f817386a03a9d2f4eb3e941efd2463', '8d85e4b1aabb4927eae63e82f4c123e8c97906', '806eb70e4a5814ddfcabf4beab699bf4773f44', '1ec27d3de36092b7a6d908ca0362804c8913dc']
# Root: ../.git/objects/51
# Directories: []
# Files: ['77abb39afe63850ba799c8e95e04b12cf5decd']
# Root: ../.git/objects/3d
# Directories: []
# Files: ['d957125f7bce5cb4ac0d8a145c1eafc51a3b56', '05dd46b4ebf1ce3d91a03a41afe55055d36331', '7d63b649b7174bda8624ae64052e59ae391d58']
# Root: ../.git/objects/58
# Directories: []
# Files: ['a30f94b8867dc61d10e5fb6af3ea1ce2b902b3']
# Root: ../.git/objects/67
# Directories: []
# Files: ['8f8c059317dbd3aa080fca3faaf4239d31c52e', 'f5274ff7968327ee96fea29a6e4f6fc5f68812', '8a384e544d8eac88124d874c13823c5ef531c1', 'c84c3481577886e74f1723a795765fe433d550']
# Root: ../.git/objects/0b
# Directories: []
# Files: ['6d147f8c8c28c753f4b5b565eb878527ba44ce', '5f3c206efebe2f77ff080fdb52fefd99aaa83a', '6593d7df34139b71bdc94e500dcd2ee53faa29']
# Root: ../.git/objects/93
# Directories: []
# Files: ['bfc9d9c1891d85be48692e956eb621bac00960', '01eef4e5de8baa9d82a6e19be685fde265aa5d']
# Root: ../.git/objects/94
# Directories: []
# Files: ['40305c3b3f3088890fa85973eb61e83256ac54']
# Root: ../.git/objects/0e
# Directories: []
# Files: ['30af43fd12db754f4061ee2d2571c42ea8ff72']
# Root: ../.git/objects/60
# Directories: []
# Files: ['d186fba6b859899658b61a311dbe455f3c4f92']
# Root: ../.git/objects/5f
# Directories: []
# Files: ['fe3f87c9e80737cdd7b838bd35e791f3bef825']
# Root: ../.git/objects/33
# Directories: []
# Files: ['2a8077191d197a9f73d6ee9d0a33ba86706c6f', 'dbd6a2482b660b5ae4bedbcbe07eea61b70a6d']
# Root: ../.git/objects/05
# Directories: []
# Files: ['3d9e8f74d56f054e46703f3c08cabe00bc8243']
# Root: ../.git/objects/9d
# Directories: []
# Files: ['38152832c8a875355c220c0407326027ce9504', '6c17ee9aaa9fd2ea0d621082d0a47739657bec', '20f2dfdc0b781b5a188d39a2c1f74cce70ec41', '1878275470fd5098c6f74927c6d020790bf655']
# Root: ../.git/objects/9c
# Directories: []
# Files: ['af295ca232d32ee89c70a6aa77db93dda891ef', 'b2a13222a2eb103b15afadbbfbadca36bf5879', '942c98dabad3037e94ef0548a9e13c13e22df9', 'fb30fb5b6f7b702bdd088d7cbf256620cd0b9d', 'a15eabdbb85f373cc9106a5db4e33f58db7fb6']
# Root: ../.git/objects/02
# Directories: []
# Files: ['47d8fd06e2d58db21f0b9319f3e76863ded940', '0b9d48e740c7a1db7eb03fce3d456849eca1c7', '30e1d4b0d586fdfa683d2e8d256194f8e1c556']
# Root: ../.git/objects/a4
# Directories: []
# Files: ['95466de75a9569e40d3834c6c8ac864ad4b1e3', '2695e9985999a326076b31f513468c7507227f']
# Root: ../.git/objects/a3
# Directories: []
# Files: ['56d95594dc05eee219b3548d02ddf49c2bb5c5']
# Root: ../.git/objects/b5
# Directories: []
# Files: ['02e90617629d025b0b988bd0d714ecbd98e5a5']
# Root: ../.git/objects/b2
# Directories: []
# Files: ['e9681d3aed5712c585a7ee36a64fffb30d6170', '7e3a178b412425e5250b08b3345f0c620b4aca', '2fdde6586908862161cb7f90b0d974a4829e4e', '1b3967f62d66d1f3dee32c8e5a855ae09dc516']
# Root: ../.git/objects/d9
# Directories: []
# Files: ['09ac0eb6446b23b5e363ab59e11ce151ee8c13', 'd5e6f300c7e6fb327360acb15684e15f514790', 'df797d312b4a745b3621629890c5b7e89adf6b']
# Root: ../.git/objects/ac
# Directories: []
# Files: ['e1da11f6f6186c87ce7d35cc9e3d133da4d8a1']
# Root: ../.git/objects/ad
# Directories: []
# Files: ['ec98e2bfcd95642786de251778a11492256ed8', '3f5a0b212ea39256d2298ed7e152fbfb794037']
# Root: ../.git/objects/d7
# Directories: []
# Files: ['934321fe4cb23016930bb6dba31e710c2c0a87', 'c5684ef4b262d93bb8ab517793ab244ccc7846', 'e28ad540f11eb7399d5c00c6095368683af7a7', '6018a9d86b252a6e314a08a071da2debd10683', '794344f18dc5c0291e30876b7aad167d9a8e50']
# Root: ../.git/objects/d0
# Directories: []
# Files: ['b4be2121ef1c95debda278f68f1b3633960dbc']
# Root: ../.git/objects/be
# Directories: []
# Files: ['ae2519f925710fe1c6aff809a9acdb9b10913a', '535c91518743c06cc881f0b0de432053cc9d26', 'ab014de798a6fb274d648468cdf01ffcfc96d8', 'aeaaf406f7a7aafb5e6ffea08be403b806952c']
# Root: ../.git/objects/b3
# Directories: []
# Files: ['4434fbd51fc88078e6c743e7e4aa0e6ed85c33']
# Root: ../.git/objects/df
# Directories: []
# Files: ['c48b07f87a453e380b02eb3c36900d7d0d3b91', '1bafb2f6577ed61613b9dc64b82324ccb0e624', 'f55dbc93c1aac2fb36f14f2ebf59d6062f8c0b', '3e9d898ea7f07ae4e09e2fb65b9caa5f341337', '61cb04f9225536b6b4bba49d5f6534d376c4a0']
# Root: ../.git/objects/da
# Directories: []
# Files: ['848bbd05e4e2c1fb9a3407698284f1e5f0d70d', '315a9f90ab756d41de877cd1d74935fe6f2115']
# Root: ../.git/objects/b4
# Directories: []
# Files: ['ac34d2cb84da6b1952cc2636889525138de82a']
# Root: ../.git/objects/a5
# Directories: []
# Files: ['7c4879ce2a1674f1b46a6873f731ba57aa79ef', '015021d1f4feb8c58c5810b21e160a36793308', '193647a4dbef4a2e9e7ef3cb96e595db99cee6']
# Root: ../.git/objects/bd
# Directories: []
# Files: ['6ba503b059fb813095866a0a9e0d34320a68c9', '078cdc17536ee7cd5be04b13d882c86c75157f', '9cb7f2e4aaf326541fd3799d05b7fa6f3a7c43']
# Root: ../.git/objects/d1
# Directories: []
# Files: ['512b8fba30cca8dd3c9088a19e5e375256c100', 'ba01f7a2fd9c1563a4ecbe4e75955d2736d961']
# Root: ../.git/objects/bc
# Directories: []
# Files: ['c4da554dcb1ab3e695f5180528b5298736c491', '674ae4620397f6ff215f51cf5bfc3d7908cacc', '805f55506537076b80e38fc21d8b20ec75a67a']
# Root: ../.git/objects/ae
# Directories: []
# Files: ['fefd0f76517c6a9f59ea8a54846d749bb3e338']
# Root: ../.git/objects/d8
# Directories: []
# Files: ['d9af94f65f9ce72d4e6ce56826207c132fe89b', '4e358a40f2dfc5b74b96811fc6edcdb5773ea5']
# Root: ../.git/objects/ab
# Directories: []
# Files: ['30d45754ac1417776f6447a051d3fa1729401c']
# Root: ../.git/objects/e5
# Directories: []
# Files: ['630d634129cf2e60d57a85e133f1e1dffcf15b', 'f31d5ab4db53c3ea706fb7010c8449cffacd21']
# Root: ../.git/objects/e2
# Directories: []
# Files: ['66bfaf39432caf61be939968daf423eab47a63', 'cba7198e0b6c271e7df763a46f52887d50867f', '8438222f5b718aaf3d75504a13f1547fd3c0e3']
# Root: ../.git/objects/f4
# Directories: []
# Files: ['5f7b570c6ad7cbbbc49bafbaa0b8538f515891']
# Root: ../.git/objects/f3
# Directories: []
# Files: ['d33a886aedf997e602f5e59e5a98925e6b81d6']
# Root: ../.git/objects/eb
# Directories: []
# Files: ['795b238df8ba6ed3a12cb56dd5e4792be963d0', 'e54063008983a94d3d8ae56e53270a1c19ec57']
# Root: ../.git/objects/c7
# Directories: []
# Files: ['46f68bd946d71e0e07c24c43ab09084e2bbb66', '911c52da0a9e755ced99f839610ca131513d15', '9ba8b5694e72b892387c6ca7fb36e48cb1fa48']
# Root: ../.git/objects/c0
# Directories: []
# Files: ['1f9df030d4d03fe38b316373a607fdfb2879bf', '5ef9d9be2e49955f56eca7441564bfdf66001c']
# Root: ../.git/objects/ee
# Directories: []
# Files: ['daecd06f45558d77c7ba4662e2d030cdeaa48e', '77ac766832ee70a859b9297271ed282e91a958']
# Root: ../.git/objects/c9
# Directories: []
# Files: ['bdf1a03d553af5dc5ce6e32468fe32889c23de', '0b07ff2fa68cdaf4c9be3a699969aabe65dbe0', 'da16777b78a71f6e65f8a4d3826576e15194ec', 'effd056cffd53cae1bd84e1e66fef2db678572', '65c5286a0fc7e4307576b4c3177d1317847182']
# Root: ../.git/objects/fc
# Directories: []
# Files: ['d3f49022d14b8392fff032aa9e0b568a8951de']
# Root: ../.git/objects/fd
# Directories: []
# Files: ['76b1fda62440e064363ec538d7e94fd367bbba', '29f58d733a4b05a7bd3e55664cdc493c2d31a1', 'ed88dc9c5dc8b0b935d3162ab485ff10438b56', 'b25ea3b5a18d195f63a667613f95fbd839e622']
# Root: ../.git/objects/f2
# Directories: []
# Files: ['0f7ecd8eaa0ebb4adc274df61034f0f850ca5e']
# Root: ../.git/objects/f5
# Directories: []
# Files: ['dbecce5b5b5d51f465fd9810b337fe9a3ae5aa', '35c3d379c3d06a6ad5fab289e9c96ade0619e3', 'ddc8c8948547bbcdd1030e601388d52dbfdf93']
# Root: ../.git/objects/e3
# Directories: []
# Files: ['1be5698113398a9102846304986e462f5ecf7d']
# Root: ../.git/objects/cf
# Directories: []
# Files: ['7725ed4aedef3410845f5b453d28ad5fa80fda']
# Root: ../.git/objects/ca
# Directories: []
# Files: ['0880052e889f289c8ba73401fbd6a70d753b4e', '80053f6dcaa3c94df5381b36221ba42d5aac74']
# Root: ../.git/objects/e4
# Directories: []
# Files: ['29b8ccf665db9cd290b81fefb3b7855ce4a9b1', 'bd0d8ba2727805853fd33f26422066770b5068']
# Root: ../.git/objects/fe
# Directories: []
# Files: ['c1f4edbc617e39c9904aba63b16d243d3d7561']
# Root: ../.git/objects/c8
# Directories: []
# Files: ['825a54953c6e8db389f4b6bdf3b431a2684315', '76cf9682de5feaf0e4ba2180365142ffcbbc52']
# Root: ../.git/objects/fb
# Directories: []
# Files: ['08bdb17d51acc34bd8e9ea112b520c44697801', '04a083e97704e229bf87bb7339e35d00615aa1']
# Root: ../.git/objects/ed
# Directories: []
# Files: ['288db018feab943a8a6565ba3a8402bffc6ec7']
# Root: ../.git/objects/c1
# Directories: []
# Files: ['94adc79e2e511b608acef76ea6df276f0a6007']
# Root: ../.git/objects/ec
# Directories: []
# Files: ['68e4c7d7d6f123b2aa404e68fd4fad554fa415']
# Root: ../.git/objects/4e
# Directories: []
# Files: ['653ae2690515202d05d74936bd5b7b813fbbb6', 'd4dac2bc54cd223ace5f01a290e1e0bc873909']
# Root: ../.git/objects/18
# Directories: []
# Files: ['c51241f94383b19495b6cef290ea79bec7af23', '233b4d58ca8f7228bdc4b5287c995f620597ca']
# Root: ../.git/objects/27
# Directories: []
# Files: ['824ab1048021a6d242249b992e4cb557576491']
# Root: ../.git/objects/4b
# Directories: []
# Files: ['ac42f78a394e1786579d8ebbd90221610a545d', '825dc642cb6eb9a060e54bf8d69288fbee4904']
# Root: ../.git/objects/pack
# Directories: []
# Files: ['pack-9138131734f5b7b3d99f07ded3a95df286c8081d.idx', 'pack-9138131734f5b7b3d99f07ded3a95df286c8081d.pack']
# Root: ../.git/objects/11
# Directories: []
# Files: ['95bd7cef80bdab7259d5dd20a84f771110c4f6']
# Root: ../.git/objects/7d
# Directories: []
# Files: ['274fdf492978c45a2ccbc63809c447f0eaa7d4', 'f6abf18c6aec5345bd9bd0d17fb3325e9c77ad']
# Root: ../.git/objects/29
# Directories: []
# Files: ['14eebadce6c57bb2c1bf40175ec5fd4c634eff', 'd5336f68894270dd1f13db01991042de7e898d']
# Root: ../.git/objects/7c
# Directories: []
# Files: ['2e73f6752fc2cc97c786dadee872ea5ffaa5c9', 'fc8bb4a9b44f9e777475839f4646da330faec4']
# Root: ../.git/objects/16
# Directories: []
# Files: ['1d35530f8b0d46414ad048691e2d65e35cc66c', 'db25f2a44bceafaef743cb1632fdfc7e6ed23e', '0e707ffe998b2176e0b879d320c7262fe786af']
# Root: ../.git/objects/42
# Directories: []
# Files: ['07249a6bcd5c99078518d2783d6877159edc78', '5495d72adbaf197b318150a4e13af9b09e838c']
# Root: ../.git/objects/89
# Directories: []
# Files: ['21f818f0621e2a2f93076fd449acb0b0afd5be', '54e1c7689138a06ac351c142c742950175bf4f', '8a504439d2bb8028f5e271f95d1db3447722d6', '64da606302028096e86ee7de4e8e21d5f6fbe1']
# Root: ../.git/objects/45
# Directories: []
# Files: ['b286665119cb64766371b22c4ff4dc5d179018']
# Root: ../.git/objects/1f
# Directories: []
# Files: ['700f203e21a749f2e6bebcc6c15476a9a47a2e', '2eaefcc19b3b556cd49d0513c2e81406c6f4f7', '7c7122faa77cad1abc31761664a724327b9d89', '90c166f44445aa3acbe17d90833fe26fcb8735']
# Root: ../.git/objects/73
# Directories: []
# Files: ['1445de9a9e3345a534d6923a630a2f2d300316', '7fad407bd595ade3e1c7e6511fb1125f2e60ea']
# Root: ../.git/objects/87
# Directories: []
# Files: ['fc64505248c4f51a9ed324441038f549f846a9']
# Root: ../.git/objects/80
# Directories: []
# Files: ['e70b8ad208d4e11429ef5333d471267f5616e2', '10bc18d83b3dc3d57c3819e130c21200247ce8', 'a985c200728faf39784a87f825588b439d2d92']
# Root: ../.git/objects/74
# Directories: []
# Files: ['6f42deb7975fe9c3983d0e61a749bfd877ecf3', '3e62dba485418a3022e22411b071571705a823', '8f5c06981bc86dc4e24bcefd511e005df3f206', '3abaf7cd2c8a760e09d895d51e928cf6468b9f']
# Root: ../.git/objects/1a
# Directories: []
# Files: ['3458dbe854a581d5f7cd105d279174882e503d', '221cc71266d0569238a74e68d3fab1fbabf901']
# Root: ../.git/objects/28
# Directories: []
# Files: ['3b253f9015d3b7246e31577129361bfc6a83ed', '1131d45a068f865395838ea495d8be9dfe60c2', '211084deb4cda4fea1f71d578a334792d43100']
# Root: ../.git/objects/17
# Directories: []
# Files: ['8b0516e47fd5d37233d79444397afa257af159', '6ffd1c5c86ad06834ba099072b0fe9ca5600c6']
# Root: ../.git/objects/7b
# Directories: []
# Files: ['26c4689564f901489773a388d11ae521919a7a', 'b2d8cf27bd223e0d505ab496e2398989b55496', 'de4393e17274b5227d47b6862ae2d7d08d6d0b']
# Root: ../.git/objects/8f
# Directories: []
# Files: ['508c957292928e5779884f58c76688c6104415', '861d42aae7729e95e8e630b52b362cd567fa46', '8e610ddd88f45d4df174ebf9e9d25eafbab052']
# Root: ../.git/objects/8a
# Directories: []
# Files: ['13602604df5095e60c8438a38afc46f0ff265d', '3cb598887262f2d38ab374e91bf38eb18004ce']
# Root: ../.git/objects/7e
# Directories: []
# Files: ['06bc3391f3d04209223881b61a1b88d7354f4d', '1b96985e64b14508028d656c56b50c72d9fd58', '8982b60ac6e9adbb1602915c6a131c3cdad2b1']
# Root: ../.git/objects/10
# Directories: []
# Files: ['06a325d1ba1b7a31404c905a225bc91ace1fb9']
# Root: ../.git/objects/19
# Directories: []
# Files: ['00e2cd8b34e3cd254f2caa953037a9ee9344e8']
# Root: ../.git/objects/4c
# Directories: []
# Files: ['86c61705769fcf23ade78fd4d797a12d65c277']
# Root: ../.git/objects/26
# Directories: []
# Files: ['165ae1abd3275919f13f1f130ac78ed48e112a']
# Root: ../.git/objects/21
# Directories: []
# Files: ['9033c44864192a2d7dd658d141f2b22a064ea4']
# Root: ../.git/objects/4d
# Directories: []
# Files: ['1dc2b5ace52a3c4afff220b222776bed36ff0c']
# Root: ../.git/objects/75
# Directories: []
# Files: ['f509b83556b79b96f4d30a6a846e85fe9383d5', '1d04b82b7679137f2fbc244960bfc5fdb84c68']
# Root: ../.git/objects/81
# Directories: []
# Files: ['984e5b62b04aec73478e04165495d43c8847c6']
# Root: ../.git/objects/44
# Directories: []
# Files: ['7171061b65c56f6c655c0c4e9ce496bec28655', '43548882296fd55fcd22362a420c4d83d698be', 'f133ef552b9cb3264145e590b390f8f015378c', 'b0138c77ec272150493918da839b26cce03af6']
# Root: ../.git/objects/2a
# Directories: []
# Files: ['f2f0d633a9f3da9c8550d115e3f0fb059b4113', '3b616a1c93c3d4406f3ca712aedb611de31bba']
# Root: ../.git/objects/2f
# Directories: []
# Files: ['464e1781f0fc3e6319a17f63341f161cd16c77', '0a27fb49e7fd0e6183f0b74601e38740fc7698', '2fc16ddd8570b545747982c75701b81be0803a']
# Root: ../.git/objects/43
# Directories: []
# Files: ['5f664a23010ef72885ff34de819026050836b5', 'ec19961b9f66858785e53d9386b766fa3525dd', '917d0c375cc688356bddcea20e0c88c3bcdad5', '8992f7f6cc4cce8c6dd4b5343c02f4562d2da7']
# Root: ../.git/objects/9f
# Directories: []
# Files: ['e37ea54cd2995e2e56ce1c3921b258631100eb']
# Root: ../.git/objects/6b
# Directories: []
# Files: ['d7615d654c09f1f4ab08b007eeaec64d8f63d7', '9c65493622d57e9394a6707679709ada6cfe50', '43ce7d9ded6abb18e71191e1ca6a89fcd49e39']
# Root: ../.git/objects/07
# Directories: []
# Files: ['e792402a1f59f14f02bb418a9fe6a6a6d7b8ea', '5b90f76f8f7afaa40bd09c61bc01c57d9547f3', 'eb62a6c2917e358dbab6b1214c07f85e6710c9']
# Root: ../.git/objects/38
# Directories: []
# Files: ['cc106e81e9b3887689e56689e5eb060386d09a']
# Root: ../.git/objects/00
# Directories: []
# Files: ['8a19420a29bf7cb62f5860aa3039e0b3418301', '3eeee14e1574ac87eee4867121d382ee0a7643']
# Root: ../.git/objects/6e
# Directories: []
# Files: ['58fb545dc05bb27a0ccd6c5bccb822e2fe847d', '16ed132f5b88114f1d0bfd787c84c1f25d516f']
# Root: ../.git/objects/9a
# Directories: []
# Files: ['787600878cb463f0c8e05f0a7b55ef52ecc8bc', 'e58960132b8d1f6903b9c0de09febe4fc4ee43', 'd5bb3e17a49f2e5ec25289e858c4caa8319a84', '590bb693990d49679ba23bf21db2c23f405e7e', 'daa1509201b1f4eaba828316ce1c22767c2b22', '99898ac05f775d1aea3cf4d45fdb87dc80b7d4']
# Root: ../.git/objects/36
# Directories: []
# Files: ['a69026002a2c7633eab6827afff1330a573b0d']
# Root: ../.git/objects/5c
# Directories: []
# Files: ['a6efa0a1dced1cb2906dd5783f064d0a39f777', '2495a19239f159495dfa3e9c1e83c9520814db']
# Root: ../.git/objects/09
# Directories: []
# Files: ['28a954e267c06b8c6bcffecda2601a2e99014f', 'cd97defd2ba3a4f310cfe87aced8a1f1892f18']
# Root: ../.git/objects/31
# Directories: []
# Files: ['79410089f5d90e31e04f54696685199aaf21f9']
# Root: ../.git/objects/info
# Directories: []
# Files: []
# Root: ../.git/objects/91
# Directories: []
# Files: ['e0a4eaa68f593de82a15f8001a8513ae65a3c3', 'edc262472aeba3220260658cb7432bf708f745', '0fabd9e82367069afb859672a2d42456e08e86', '64204d06f93cf809932bf74c70e446264cb01f']
# Root: ../.git/objects/62
# Directories: []
# Files: ['1a8b9e36a3136f1d45b80ecfb4d3541d16b682', '289f50d111e9784a3097631fcfa17d303f0276']
# Root: ../.git/objects/3a
# Directories: []
# Files: ['7eea9e5fd2df57b0daf883efa23c16f0d84ce1']
# Root: ../.git/objects/54
# Directories: []
# Files: ['24b12d741859af469f597f4a9b94b0bf4bd5d2', 'b3f66314b160e75d1cded0baaec7321037347d', '4027b74967888eba497399c18df77bf25548ae', 'e8ba888329c6228932d2367aaba7b21faefc4f', '61d3a651ad986d1be20e66c074723bca80c5f4']
# Root: ../.git/objects/53
# Directories: []
# Files: ['1fd3a4e0c19b929f761fba666b565738935dce', 'b17bcbf3f644b1cc4a1815aa82f8706d782047', 'bf495a98b3ea02a600160f6bf548e6034c773f']
# Root: ../.git/objects/3f
# Directories: []
# Files: ['5f755d761876885d4372c5dfb2d2041e349afa', 'e1231b2a25d95087b9cba43165aab6c2e3428a']
# Root: ../.git/objects/30
# Directories: []
# Files: ['388cc041248e36b358c6819879dda41ceeebc0']
# Root: ../.git/objects/5b
# Directories: []
# Files: ['5a84e49dae5538b5eaa6c8e3d999dd1e128c98']
# Root: ../.git/objects/37
# Directories: []
# Files: ['fe9752aa4ff2b3923bc31eee4b1b7cd1570849']
# Root: ../.git/objects/6d
# Directories: []
# Files: ['e20e38468608bd724bdc3d147f5b5a4705ab50', 'ceaa893235f76e1ac12471d1a0d5a66e9d2afe', '51c12dfae3219e64b6d81c543fb81e3e9a8a19']
# Root: ../.git/objects/01
# Directories: []
# Files: ['6d924973c0d63c1ee446c43ad6fbd8d0c498aa', 'c41a7402e16c807729519f798f6b30bd950534']
# Root: ../.git/objects/06
# Directories: []
# Files: ['ea866803c8d63e5e889dac865654ee9b20c352', '2c1da9cd257a07baf91f84dd0583d170e8c257', '94b458c1b9bd6fd8ab6c6299de2b3814c3c4c2', '3fb89fd19dc87ca54c04c830d842e3b49a5f5a']
# Root: ../.git/objects/39
# Directories: []
# Files: ['929c074718c7549fff558fd35aeaaeb2cfecc0', '542a6b53621d44a9d33b84c05790ac24f14bff', '8e1ef9edd5569999a836e51f7feb16990b1d82']
# Root: ../.git/objects/99
# Directories: []
# Files: ['4b6f3e01e4601d0200e6d5ae7e5245dcef263d']
# Root: ../.git/objects/52
# Directories: []
# Files: ['d506073da6c8887d13fb5dd6bad0a8d26034bd', 'c66c41eece0a4bd5d2d299193e48b910c3cfd1']
# Root: ../.git/objects/55
# Directories: []
# Files: ['598cafc066db7f4948e66b24336217b00cdc9f', '31f734cf57c80cf9551c2f16275c4106dfcb50', '9de9d46ea1e139c96cfc74ce8bac6a48ee0c6a']
# Root: ../.git/objects/0f
# Directories: []
# Files: ['833c04da484f5371e679e8609735133e971f68', '0d5b18ee5f77ab46d8ad2f918f044d3202b5d8', '48f8a2e30811e85a00eb18a6cfe8947098bcaf', 'de29c0120f86400b9089a91be6775319ed3890']
# Root: ../.git/objects/0a
# Directories: []
# Files: ['b9e1df4b0ac0c2953cac8ac139e9aabdd6ddb3', '663c813dd6ace426ad2f28c0f412aa2ef8cf2d']
# Root: ../.git/objects/90
# Directories: []
# Files: ['872cc3f6d9190bf5215fe4c409fce54d8ebd42', 'c2ce8da27836f49e52f1cf78664ec7bf2b7de9']
# Root: ../.git/objects/bf
# Directories: []
# Files: ['f3a29cefb5caff5cc2c95dcbebb8cfa526b06f']
# Root: ../.git/objects/d3
# Directories: []
# Files: ['7117b33cf9c9e993bd9b9c1e3c945b91452330']
# Root: ../.git/objects/ba
# Directories: []
# Files: ['1e3a9642e65663af4b5523a1e31b69ca13e929', '83ecb4874549114ae6890c7c3c1204d3b2199b']
# Root: ../.git/objects/a0
# Directories: []
# Files: ['6b449b54d9e46d77c7d3b09102945b338bf749']
# Root: ../.git/objects/a7
# Directories: []
# Files: ['55a8e3e2bbefcd0a8f92bf79ec1cac19355039', '0814c2b1dc1a891be11398146e84c618854782', '9984c71f7f5db1f7670a9684e08e47e258e1b5']
# Root: ../.git/objects/b8
# Directories: []
# Files: ['a80565f43de4ad9f9940a18acbc0ea432f5593', 'ce2dcbf9879e26392056e4bbf7a0acf3c9bc1a']
# Root: ../.git/objects/b1
# Directories: []
# Files: ['e113dd1b8041c60539afe150266d117fd76348']
# Root: ../.git/objects/dd
# Directories: []
# Files: ['1bd24f1a0228d260732e03d07c93a41897da59']
# Root: ../.git/objects/dc
# Directories: []
# Files: ['050642aa7e34963d7ca3a6da4a514d47568866']
# Root: ../.git/objects/b6
# Directories: []
# Files: ['e6269e38a98cb233038171215f442a9c3a407e']
# Root: ../.git/objects/a9
# Directories: []
# Files: ['7582be7ed4663159ae0566207e2a9546b1b252']
# Root: ../.git/objects/d2
# Directories: []
# Files: ['88c47f04fc16c1394b0c68b4b3a87617e61ab3', '15a51b77435b9ad27589b101377a4098e7d2bb']
# Root: ../.git/objects/aa
# Directories: []
# Files: ['2f6a3cc259baa0a61d891db1fec9b751488391', '3918a27056641a9dd8fb146aacb4e6a170e231', '9678946e81a8ed13425405651c14598c541d00', '14e687309af8cdd43778e2b20b57be5116065e']
# Root: ../.git/objects/af
# Directories: []
# Files: ['1da1a461008821d812c4a0fd5d864ba7713d70']
# Root: ../.git/objects/b7
# Directories: []
# Files: ['a4e46a2833e2b4b122016a750a00d1370d715a', 'a4b56716cee8185c516ca882eb446bae77c553']
# Root: ../.git/objects/db
# Directories: []
# Files: ['499bc48f1c5ea6340d0d444290a22c35e19c36', '4957c02ce7f137e348f475fad3af6834c45b83']
# Root: ../.git/objects/a8
# Directories: []
# Files: ['9975723faf45e60bee2d6a89c3d8463499d9c3', '842210b1a443de9110a7b33bab6870b8987f61']
# Root: ../.git/objects/de
# Directories: []
# Files: ['9ea69dc9dd7c62881fb46e191f3488e1f2ef8e', 'db5a7f816a37b88151c8e23fed0624683a536d']
# Root: ../.git/objects/b0
# Directories: []
# Files: ['ac28da9a36e7a40dffc7a381bd6560beeac49b', '0fff8ff6ce361b2177bf3aad96dfb7cac45490']
# Root: ../.git/objects/a6
# Directories: []
# Files: ['0bb41386750288227af5de699486e170ffe8bf', 'e5d87f27f621f70fae989badbe36dee873968d', '2171af5fade96e0d54ecfa5d8922611312d6bf']
# Root: ../.git/objects/b9
# Directories: []
# Files: ['2ef5d97a6e00bc95d7642b813ac70b0b2663a8']
# Root: ../.git/objects/ef
# Directories: []
# Files: ['6ba48b17146be61a06998a26faa165bd391c42', 'dd61d6a063f8697db7aadfc78228d9c7305dad', '45b8317713ad0af403db4074607fb5f300598a']
# Root: ../.git/objects/c4
# Directories: []
# Files: ['ff0cb673f9ee0f029cce052e17416131314c9d']
# Root: ../.git/objects/ea
# Directories: []
# Files: ['ab198635374db498b0ebe392bbfe52505a2ff4', '4682d0db8aa02fdf0ee07c66fcd707a8a334e7']
# Root: ../.git/objects/e1
# Directories: []
# Files: ['2f6aee0ae05edce25abc0dab55e5b63e85f6ee']
# Root: ../.git/objects/cd
# Directories: []
# Files: ['a4d71aefc8bac00ee69a13b2fe819d5f142955', 'be6b1b9155a40942d88a2eee0e382d417df095']
# Root: ../.git/objects/cc
# Directories: []
# Files: ['bdbcda38b91122089fcf4560ee32c98fac8576']
# Root: ../.git/objects/e6
# Directories: []
# Files: ['5b79f9b166a03f92c476c3af874e0e81cddc4b', 'f2bf5c695ab2a50dfb85d36a3b76e00afb5d54', 'f4883f14cfa8ee7bed125724a63487e3442d35']
# Root: ../.git/objects/f9
# Directories: []
# Files: ['359f47bad7140d23fdb3037a72af91c345c9a0', '6dd953dfa994dbdf5b0fa250596e55f4313b26', '9077c8636c3e97aeda329eb25cea27d7aab12f', '5b7ae53d2572be0a8fa00e430ab9fc546630b1']
# Root: ../.git/objects/f0
# Directories: []
# Files: ['7eb1fcb58edc034eea433ccece39049f777cee', 'dcd996fc577150a60289245b375a9e91e70cf8']
# Root: ../.git/objects/f7
# Directories: []
# Files: ['9c4f4302eb0debf8668abbd14a6a8509b5e878', '040e2bf1ff9b7c69b35274709ad88983162dc8']
# Root: ../.git/objects/e8
# Directories: []
# Files: ['c84efe781942b746794b0c8aa203ad52ead64a', '1c83fd89f0928375d18995edda4c5bdedfb8fb']
# Root: ../.git/objects/fa
# Directories: []
# Files: ['5c2464dc859cfca02838a302667d9390727b2f']
# Root: ../.git/objects/ff
# Directories: []
# Files: ['38a7de80ef158ec3edd3c4d540b0e3b0ff8222']
# Root: ../.git/objects/c5
# Directories: []
# Files: ['e7a3c4bdf1fc4dd7be9e1f136708864373356a', 'f4a4a8100e98e670201907ffc8a0c3e721a82b']
# Root: ../.git/objects/c2
# Directories: []
# Files: ['6c856865dc2dc87678a2deb42f3c1faca0eddf', '12ee7378be20bd349afe4b749f5e0e6ae78a93', '63842ce6a6fa6b214f976469e330d67cca60f5']
# Root: ../.git/objects/f6
# Directories: []
# Files: ['f290a22c769089f085414fcb0b1264527df2a8', 'ff64ba32b748574f99732cd1c10bbec469e5bd']
# Root: ../.git/objects/e9
# Directories: []
# Files: ['e9f33f39af78ef48811de23c9595852a810775', 'bbff7d6dcc98b57bd6436d1247b8a422ff7667']
# Root: ../.git/objects/e7
# Directories: []
# Files: ['c8f35c5bb7345f03ecac76316db6f2951376c0', '55ac434dd3baa3d5950490b3226915c56b5b04', '45c17eadaf9600082ad9e957a67eb3b98f8650']
# Root: ../.git/objects/cb
# Directories: []
# Files: ['1ef55147456c7c72474a9b076855d9932f6ad2', '8fb296f2c2eb211b60a849745cabd4e1d10c7e', '4013fb89fa20e3ed6276c79d5832ddc7414695']
# Root: ../.git/objects/f8
# Directories: []
# Files: ['874c0b7e22625070e12e73524e416dd098f3fc', '094e95e6306c738c29f542e6ee407e75b178e7']
# Root: ../.git/objects/ce
# Directories: []
# Files: ['59af51cc999803195f73b4f41e36c139ee4ca8', '122ec02be28c9727bdd58ca7adf8f7ec6cfae8']
# Root: ../.git/objects/e0
# Directories: []
# Files: ['7230729076a92eb42b13ca092e05a5d48d94f4', '74c5f6bb8b0e518cb8d293f14a58949ad0c26c', 'bdd81face06a0f5339464f0313ad37eb4ecd9f']
# Root: ../.git/objects/46
# Directories: []
# Files: ['4e975973b5af507524796bdb72e3551354e1fa', '6d95966225a8c8ef58e55844d0167cfccb35a6']
# Root: ../.git/objects/2c
# Directories: []
# Files: ['5ee593e94fec3bbbc6264a00d576a7db84ae8b', 'a7109331b6c0eb30053fa210ec70f1d568715d']
# Root: ../.git/objects/79
# Directories: []
# Files: ['7493ff76bb29cefb394722305b8c8d0753fa94', '425d8e6dd503c63f3489d8702d7e4cbc00c036', '4cabc1fd419a27aeb2ac58d37ecfd66ece6413', '4d3e0247ed300df5ce9d40df6132658f54e0b2']
# Root: ../.git/objects/2d
# Directories: []
# Files: ['b4fa737e6c5e1a78a4f4fe19926a100b9844be', '716b1fa6d14b63e4b0394fbb83b499e47d50ed', '8c07bdeeda8c452fe2e9053eb181a3c15bc665', 'd10b42aa18918bb3f850899d88970512b5b79e']
# Root: ../.git/objects/41
# Directories: []
# Files: ['f4fcdae52717fefcc37343c9fb4cc11f4ec9c9']
# Root: ../.git/objects/83
# Directories: []
# Files: ['84728c695bd538c3d852d43207e3d0bfd7ef3d']
# Root: ../.git/objects/1b
# Directories: []
# Files: ['4ead3f341fd5846337dc53fca6984719273862', '9240949ef935ab2edd48fcf49cf4d1ae72e850']
# Root: ../.git/objects/77
# Directories: []
# Files: ['90486437563a1083870e1f3f4bfbee5e32b9f1', '88b20bfd805eb72bf40c746a407c2ac0e5790b', '0f74a13255b208049f289f5d1f16ce0dc4f127']
# Root: ../.git/objects/70
# Directories: []
# Files: ['149fc9d3ca56e76c36427070c08ccff7af7cc8', 'fe35a988fd1e024cb76ccbb8dfab78fbfa4a9c', 'b62fb3ec6ad3fb462fbef3403f05f8711848be', '153469fbbccc268dc19026f08bef48df9e1987', '5bc6fb957a02b2885f5d3bf9c464e4c47fecb2']
# Root: ../.git/objects/24
# Directories: []
# Files: ['f03e1f544919f1b191b7a0914fb8834eca7523']
# Root: ../.git/objects/4f
# Directories: []
# Files: ['9d079a8c05d943395d22d577b3b084a4a54ea1', '424c4dc7e162d7108c38bb5869dc4d87e1b6f9']
# Root: ../.git/objects/8d
# Directories: []
# Files: ['9f138eb2048f1d3fc57df12a6bbb6f84bd86be']
# Root: ../.git/objects/15
# Directories: []
# Files: ['a67795e678c3b0cea65c5c3b3ede230a3d51ee', '8aba8fd1de418761ef232b0191ea604f694ca3', 'ef6862728a4a4edcd616fcca79122f895ceace']
# Root: ../.git/objects/12
# Directories: []
# Files: ['3304e0be446cefce0f29cc47ac636dea86f53d', 'ebd3ad134868512e522613d0b44958ef112fac', '74072d19f5a3fe03763ac4daa468805f05cd29']
# Root: ../.git/objects/8c
# Directories: []
# Files: ['e1467dca38ee50eb4318b3ff45d699683f280f', 'ed8ab2412eb5ed6f5eb5e79954014ee913e2c0']
# Root: ../.git/objects/85
# Directories: []
# Files: ['38dd1dc763a8d9e77063acf9a61559553dd51e', 'f95eddc3f4a71aec8c40bf6e6651a08ae31723', '954eabcfc32c9ef6765ae90ef192256664874e']
# Root: ../.git/objects/1d
# Directories: []
# Files: ['bc48834d92e93c3e70bb80e9eafb2fbe6a58a6', '8584da908f464b5ea8162aa7e6d52dc9db49e8', '81ee06dea29730ff641158d516e2bf68fdc7dc']
# Root: ../.git/objects/71
# Directories: []
# Files: ['ba260ce30bfca11032570fc397745df9292b7d', '1906991aa1fdf9eb49cfa0e016c05e93b6790b', '226a5bb08f0b1fe0bc290618c6c21de6c6aa6e', '7eff206fd0428fcd1133253f1fdfada62cc09c']
# Root: ../.git/objects/76
# Directories: []
# Files: ['210a2f99558b59d25fa57acbd2282d07d62f44']
# Root: ../.git/objects/1c
# Directories: []
# Files: ['4b97e22710d4b7c20dc423d331efce543f56f2']
# Root: ../.git/objects/82
# Directories: []
# Files: ['161b2d77c9a66bf3a80a1fc39f555350561e95', 'ac0f93221ee3c36b5ab3c24505c0b316c49f5d']
# Root: ../.git/objects/49
# Directories: []
# Files: ['bea6ae12fc7337d84c4de87993844e43a102af', 'ba64e3cf5ec3eb16c62316b242dcf355059f5b']
# Root: ../.git/objects/40
# Directories: []
# Files: ['84faa712e2abccec972a9266cdbe68f1f4e060', '4f1130fdd97d25e5ad6da9139a19a1a694a721']
# Root: ../.git/objects/2e
# Directories: []
# Files: ['fece5395f14dd5308fc02313833ead0d995c9c', '133bd80a7b44c0e469d91ba1a2c6cee23b4864', '1a411ae13e8005dc6dc8bd06734e57c39f9f3a', '787867b1144a74b2d802d13b077693e09f8b62']
# Root: ../.git/objects/47
# Directories: []
# Files: ['2a358fe91b8cef3484893b2269461ad49c8929', '8e34dcdcb9be7cf30d153d198131e7fdb88019', 'd1373d60af93958f4b73777da93440631d7ef3']
# Root: ../.git/objects/78
# Directories: []
# Files: ['bc99de7fc401626a09083951e06f977dda84a1', '4f3fda555e65b7d0d428476fd0c051bc6732f1', '5bed7662f3d6cfa40582fbf8b240c1a726be8e', '2dac3f5b44089d9b801aa1d5f45a9594a71abd', '3d05928c4109931b2a72257db78e7528d9f1ef', 'cc2b9b838434b03212e7cab4e24d61629c4ba3', 'ecc3216c6d5fa0de434b0208b3f726ad1fb267']
# Root: ../.git/objects/8b
# Directories: []
# Files: ['8a4e784f109f561c21929956dcaf1cb32dfd13', 'c2378fbb0923b9e0f748dabab8e18aa4e22446']
# Root: ../.git/objects/13
# Directories: []
# Files: ['f5dde36492c61635a144bd619814ba4f2dca4c']
# Root: ../.git/objects/7f
# Directories: []
# Files: ['7f7070673857d7c1325c6ad47fc50224bad00c', '5abdc89b050407cadad46fa3574e15d58dd5a4']
# Root: ../.git/objects/7a
# Directories: []
# Files: ['e7f6cbe902f0230bd8dd63eb967a39d7c75f43']
# Root: ../.git/objects/8e
# Directories: []
# Files: ['95aebca5e92ea0fadfdde6a59a7f3dc648cda5']
# Root: ../.git/objects/22
# Directories: []
# Files: ['7315e08a86c21ab5c7732d39482119ad9804d1']
# Root: ../.git/objects/25
# Directories: []
# Files: ['0fd5d84980904ee7494a2ceddd34ebb02450aa', 'bc50b6356a894b144b485f9780d9720f4438f1']
# Root: ../.git/objects
# Directories: ['61', '0d', '59', '92', '0c', '66', '3e', '68', '57', '3b', '03', '9b', '9e', '04', '6a', '32', '35', '69', '3c', '56', '51', '3d', '58', '67', '0b', '93', '94', '0e', '60', '5f', '33', '05', '9d', '9c', '02', 'a4', 'a3', 'b5', 'b2', 'd9', 'ac', 'ad', 'd7', 'd0', 'be', 'b3', 'df', 'da', 'b4', 'a5', 'bd', 'd1', 'bc', 'ae', 'd8', 'ab', 'e5', 'e2', 'f4', 'f3', 'eb', 'c7', 'c0', 'ee', 'c9', 'fc', 'fd', 'f2', 'f5', 'e3', 'cf', 'ca', 'e4', 'fe', 'c8', 'fb', 'ed', 'c1', 'ec', '4e', '18', '27', '4b', 'pack', '11', '7d', '29', '7c', '16', '42', '89', '45', '1f', '73', '87', '80', '74', '1a', '28', '17', '7b', '8f', '8a', '7e', '10', '19', '4c', '26', '21', '4d', '75', '81', '44', '2a', '2f', '43', '9f', '6b', '07', '38', '00', '6e', '9a', '36', '5c', '09', '31', 'info', '91', '62', '3a', '54', '53', '3f', '30', '5b', '37', '6d', '01', '06', '39', '99', '52', '55', '0f', '0a', '90', 'bf', 'd3', 'ba', 'a0', 'a7', 'b8', 'b1', 'dd', 'dc', 'b6', 'a9', 'd2', 'aa', 'af', 'b7', 'db', 'a8', 'de', 'b0', 'a6', 'b9', 'ef', 'c4', 'ea', 'e1', 'cd', 'cc', 'e6', 'f9', 'f0', 'f7', 'e8', 'fa', 'ff', 'c5', 'c2', 'f6', 'e9', 'e7', 'cb', 'f8', 'ce', 'e0', '46', '2c', '79', '2d', '41', '83', '1b', '77', '70', '24', '4f', '8d', '15', '12', '8c', '85', '1d', '71', '76', '1c', '82', '49', '40', '2e', '47', '78', '8b', '13', '7f', '7a', '8e', '22', '25']
# Files: []
# Root: ../.git/info
# Directories: []
# Files: ['exclude']
# Root: ../.git/logs/refs/heads
# Directories: []
# Files: ['main']
# Root: ../.git/logs/refs/remotes/origin
# Directories: []
# Files: ['HEAD', 'main']
# Root: ../.git/logs/refs/remotes
# Directories: ['origin']
# Files: []
# Root: ../.git/logs/refs
# Directories: ['heads', 'remotes']
# Files: ['stash']
# Root: ../.git/logs
# Directories: ['refs']
# Files: ['HEAD']
# Root: ../.git/hooks
# Directories: []
# Files: ['commit-msg.sample', 'pre-rebase.sample', 'pre-commit.sample', 'applypatch-msg.sample', 'fsmonitor-watchman.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'post-update.sample', 'pre-merge-commit.sample', 'pre-applypatch.sample', 'pre-push.sample', 'update.sample', 'push-to-checkout.sample']
# Root: ../.git/refs/heads
# Directories: []
# Files: ['main']
# Root: ../.git/refs/tags
# Directories: []
# Files: []
# Root: ../.git/refs/remotes/origin
# Directories: []
# Files: ['HEAD', 'main']
# Root: ../.git/refs/remotes
# Directories: ['origin']
# Files: []
# Root: ../.git/refs
# Directories: ['heads', 'tags', 'remotes']
# Files: ['stash']
# Root: ../.git
# Directories: ['objects', 'info', 'logs', 'hooks', 'refs']
# Files: ['ORIG_HEAD', 'config', 'HEAD', 'description', 'index', 'packed-refs', 'COMMIT_EDITMSG', 'FETCH_HEAD']
# Root: ../data
# Directories: []
# Files: ['HeightWeight.csv', '.DS_Store', 'Car Electronics.csv', '03_city_edmonton_assessment_small.csv', 'sportsref_download.xlsx', 'Salary_Survey.csv', 'threads_reviews.csv', 'train.csv', '03_city_edmonton_assessment_sample.csv', 'chipotle.tsv', 'cars.csv', 'titanic_train.csv', 'spam.csv']
# Root: ../workbooks/file_list
# Directories: []
# Files: ['002_conditional_statements_sol.ipynb', '021_big_review.ipynb', '001a_python_example.py', '010_class_comments.ipynb', '011_looping_2_data.ipynb']
# Root: ../workbooks/__pycache__
# Directories: []
# Files: ['helper.cpython-310.pyc']
# Root: ../workbooks/zz_OLD/file_list
# Directories: []
# Files: ['002_conditional_statements_sol.ipynb', '021_big_review.ipynb', '001a_python_example.py', '010_class_comments.ipynb', '011_looping_2_data.ipynb', '005_file_access.ipynb']
# Root: ../workbooks/zz_OLD/development_working_dir/file_list
# Directories: []
# Files: ['Clothing.csv']
# Root: ../workbooks/zz_OLD/development_working_dir
# Directories: ['file_list']
# Files: ['010_class_comments.ipynb', 'Clothing.csv', '017a_cards_sol.ipynb', '020_string_processing_regex_sol.ipynb', '005_file_access.ipynb', '006_objects.ipynb', 'residential.csv', 'Cycling.csv', '002_conditional_statements.ipynb', 'z00_classes.ipynb', 'overloading_sol.ipynb', 'cards_sol.py', '005a_File_Loading_example_from_stats.ipynb', '004_functions.ipynb', '009_strings_sol.ipynb', 'cards_3_import_sol.ipynb', '024_cards_ipython.ipynb', '018_cards_part_2_sol.ipynb', 'abstract_class.ipynb', '013_arrays_and_numpy_sol.ipynb', 'run_from_command.py', '021_big_review_sol.ipynb', 'inheritance.ipynb', 'poker_gui.ipynb', '011_looping_2_data_sol.ipynb', '025_refactor_cards_gui_sol.ipynb', 'car.ipynb', '014_map_apply_sol.ipynb', 'Strength Training.csv', 'file_list.zip', 'helper.py', '012_algorithm_design.ipynb', 'date_data_sol.ipynb', 'multip_inh.ipynb', '022_abstract_multip_inh_sol.ipynb', 'cards_sol_2.py', 'residential2.csv', 'difference.csv', '016_file_management_2_sol.ipynb', '000_Setup.ipynb', '001a_python.py', '023_functional.ipynb', 'diffs.csv', 'tmp.ipynb', 'car_inh.py', '001_programming_basics.ipynb', 'arrays_and_numpy_sol.ipynb', 'search_sort.ipynb', 'string_processing.ipynb', '017_args_kwargs_sol.ipynb', '007_other_data_structures.ipynb', '003_loops.ipynb', 'cards_sol_3.py', '008_recursion.ipynb']
# Root: ../workbooks/zz_OLD
# Directories: ['file_list', 'development_working_dir']
# Files: ['fib.csv', 'file_list.zip', 'dl_process.ipynb', 'difference.csv', 'diffs.csv']
# Root: ../workbooks
# Directories: ['file_list', '__pycache__', 'zz_OLD']
# Files: ['002_conditional_statements_sol.ipynb', '021_big_review.ipynb', '001a_python_example.py', '010_class_comments.ipynb', '011_looping_2_data.ipynb', '001_programming_basics_sol.ipynb', '017a_cards_sol.ipynb', '020_string_processing_regex_sol.ipynb', '025_refactor_cards_gui.ipynb', '005_file_access.ipynb', '007_other_data_structures_full_sol.ipynb', '018_cards_part_2.ipynb', '019_cards_3_import.ipynb', '017_inheritance.ipynb', 'cards_sol_1.py', '006_objects.ipynb', '012_algorithm_design_sol.ipynb', '017_inheritance_sol.ipynb', '002_conditional_statements.ipynb', '004_functions_sol.ipynb', '003_loops_sol.ipynb', '023_search_sort.ipynb', '005a_File_Loading_example_from_stats.ipynb', '004_functions.ipynb', '009_strings_sol.ipynb', '016_file_management_2.ipynb', '024_cards_ipython.ipynb', '018_cards_part_2_sol.ipynb', '013_arrays_and_numpy_sol.ipynb', '009_strings.ipynb', '011_looping_2_data_sol.ipynb', '025_refactor_cards_gui_sol.ipynb', '014_map_apply.ipynb', '022_abstract_multip_inh.ipynb', '014_map_apply_sol.ipynb', '006_objects_sol.ipynb', 'fib.csv', '017_args_kwargs.ipynb', '023_search_sort_sol.ipynb', '018_cards_part_2_akeem_in_class.ipynb', 'file_list.zip', 'helper.py', '012_algorithm_design.ipynb', '020_string_processing_regex.ipynb', '024_cards_ipython_sol.ipynb', '022_abstract_multip_inh_sol.ipynb', 'cards_sol_2.py', '013_arrays_and_numpy.ipynb', '016_file_management_2_sol.ipynb', '000_Setup.ipynb', 'chipotle.tsv', '015_overloading_sol.ipynb', '019_cards_3_import_sol.ipynb', '001_programming_basics.ipynb', '008_recursion_sol.ipynb', '017_args_kwargs_sol.ipynb', '007_other_data_structures.ipynb', '003_loops.ipynb', 'cards_sol_3.py', '017a_cards.ipynb', '005_file_access_sol.ipynb', '015_overloading.ipynb', '008_recursion.ipynb']
# Root: ../
# Directories: ['supplementary_practice_workbooks', 'reference_material', 'images', 'course_material', '.git', 'data', 'workbooks']
# Files: ['.DS_Store', 'README.md', '.gitignore']

# %% [markdown]
# ## Exercise
#
# Attempt to list the folders and files in the level above where this notebook is located. Create a list of folders and a list of files. Return them in a tuple.

# %%
def genList(path="../"):
    folders = []
    files = []
    for root, directories, files in os.walk(path):
        #folders.append(root)
        folders.append(directories)
        files.append(files)
    return folders, files

# %%
genList()
# Out:
# ([['supplementary_practice_workbooks',
#    'reference_material',
#    'images',
#    'course_material',
#    '.git',
#    'data',
#    'workbooks'],
#   ['moodle_exercises'],
#   [],
#   ['docs_and_guides', 'slides'],
#   [],
#   ['zz_OLD'],
#   ['Repository', 'Used'],
#   [],
#   [],
#   [],
#   ['labs', 'assignments', 'exams', 'documents'],
#   ['lab1', 'lab6', 'lab0', 'lab5', 'lab2', 'lab3', 'lab4'],
#   ['github'],
#   ['test', 'workflows'],
#   [],
#   [],
#   ['github'],
#   [],
#   ['github'],
#   ['test', 'workflows'],
#   [],
#   [],
#   ['github'],
#   [],
#   ['__pycache__', 'github'],
#   [],
#   [],
#   ['__pycache__', 'github'],
#   [],
#   [],
#   ['github'],
#   [],
#   ['asn1', 'asn2'],
#   ['data'],
#   [],
#   ['data'],
#   [],
#   ['exam_3', 'exam_2', 'exam_1'],
#   [],
#   [],
#   ['applied', 'written'],
#   [],
#   [],
#   [],
#   ['objects', 'info', 'logs', 'hooks', 'refs'],
#   ['61',
#    '0d',
#    '59',
#    '92',
#    '0c',
#    '66',
#    '3e',
#    '68',
#    '57',
#    '3b',
#    '03',
#    '9b',
#    '9e',
#    '04',
#    '6a',
#    '32',
#    '35',
#    '69',
#    '3c',
#    '56',
#    '51',
#    '3d',
#    '58',
#    '67',
#    '0b',
#    '93',
#    '94',
#    '0e',
#    '60',
#    '5f',
#    '33',
#    '05',
#    '9d',
#    '9c',
#    '02',
#    'a4',
#    'a3',
#    'b5',
#    'b2',
#    'd9',
#    'ac',
#    'ad',
#    'd7',
#    'd0',
#    'be',
#    'b3',
#    'df',
#    'da',
#    'b4',
#    'a5',
#    'bd',
#    'd1',
#    'bc',
#    'ae',
#    'd8',
#    'ab',
#    'e5',
#    'e2',
#    'f4',
#    'f3',
#    'eb',
#    'c7',
#    'c0',
#    'ee',
#    'c9',
#    'fc',
#    'fd',
#    'f2',
#    'f5',
#    'e3',
#    'cf',
#    'ca',
#    'e4',
#    'fe',
#    'c8',
#    'fb',
#    'ed',
#    'c1',
#    'ec',
#    '4e',
#    '18',
#    '27',
#    '4b',
#    'pack',
#    '11',
#    '7d',
#    '29',
#    '7c',
#    '16',
#    '42',
#    '89',
#    '45',
#    '1f',
#    '73',
#    '87',
#    '80',
#    '74',
#    '1a',
#    '28',
#    '17',
#    '7b',
#    '8f',
#    '8a',
#    '7e',
#    '10',
#    '19',
#    '4c',
#    '26',
#    '21',
#    '4d',
#    '75',
#    '81',
#    '44',
#    '2a',
#    '2f',
#    '43',
#    '9f',
#    '6b',
#    '07',
#    '38',
#    '00',
#    '6e',
#    '9a',
#    '36',
#    '5c',
#    '09',
#    '31',
#    'info',
#    '91',
#    '62',
#    '3a',
#    '54',
#    '53',
#    '3f',
#    '30',
#    '5b',
#    '37',
#    '6d',
#    '01',
#    '06',
#    '39',
#    '99',
#    '52',
#    '55',
#    '0f',
#    '0a',
#    '90',
#    'bf',
#    'd3',
#    'ba',
#    'a0',
#    'a7',
#    'b8',
#    'b1',
#    'dd',
#    'dc',
#    'b6',
#    'a9',
#    'd2',
#    'aa',
#    'af',
#    'b7',
#    'db',
#    'a8',
#    'de',
#    'b0',
#    'a6',
#    'b9',
#    'ef',
#    'c4',
#    'ea',
#    'e1',
#    'cd',
#    'cc',
#    'e6',
#    'f9',
#    'f0',
#    'f7',
#    'e8',
#    'fa',
#    'ff',
#    'c5',
#    'c2',
#    'f6',
#    'e9',
#    'e7',
#    'cb',
#    'f8',
#    'ce',
#    'e0',
#    '46',
#    '2c',
#    '79',
#    '2d',
#    '41',
#    '83',
#    '1b',
#    '77',
#    '70',
#    '24',
#    '4f',
#    '8d',
#    '15',
#    '12',
#    '8c',
#    '85',
#    '1d',
#    '71',
#    '76',
#    '1c',
#    '82',
#    '49',
#    '40',
#    '2e',
#    '47',
#    '78',
#    '8b',
#    '13',
#    '7f',
#    '7a',
#    '8e',
#    '22',
#    '25'],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   ['refs'],
#   ['heads', 'remotes'],
#   [],
#   ['origin'],
#   [],
#   [],
#   ['heads', 'tags', 'remotes'],
#   [],
#   [],
#   ['origin'],
#   [],
#   [],
#   ['file_list', '__pycache__', 'zz_OLD'],
#   [],
#   [],
#   ['file_list', 'development_working_dir'],
#   [],
#   ['file_list'],
#   []],
#  ['Clothing.csv', [...]])

# %% [markdown]
# #### Exists
#
# We can also check if a file or folder exists. This is useful if we're going to be creating a new file or folder, and we want to make sure we don't overwrite something that already exists.

# %%
print(os.path.exists("chipotle.tsv"))
print(os.path.exists("mad_bitcoin_keys.tsv"))
# Out:
# True
# False

# %% [markdown]
# ### File Paths
#
# When navigating file systems we necessarily need to deal with file paths, or the locations in the file structure where each file is located. There are two types of file paths, absolute and relative.
#
# ![Paths](../images/paths.png "Paths")
#
# #### Absolute Paths
#
# An absolute path is the full path to a file or folder. It starts at the root of the file system and lists each folder in the hierarchy, separated by a slash. For example, on my Mac, the root of the file system is "/". If I want to get to my home folder, I need to go to "/Users/". If I want to get to my Documents folder, I need to go to "/Users/akeem/Documents". If I want to get to my "downloads" folder, I need to go to "/Users/akeem/Downloads".
#
# Absolute file paths will rarely be relevant for us, it is relevant if you are writing lower level programs, that deal more directly with a file system. Note that different operating systems have different file systems, so the absolute path on a Mac is different than the absolute path on a PC - you can't rely on any particular configuration.
#
# <b>Note:</b> those environment variables that we mentioned above are some of the things that tell programs where to look for stuff, they indicate the root directories of things like the user's home folder, or the location of the program files.
#
# #### Relative Paths
#
# Relative paths are relative to the current working directory. If I am in the root directory of this repository, the relative path to each workbook is workbooks\workbook_name.ipynb. If I am in the workbooks folder, the relative path to each workbook is just the name of the workbook. If I am in the data folder, the relative path to each workbook is ../workbooks/workbook_name.ipynb.
#
# When working within a repository we use relative paths to refer to other files. This allows us to pass around the repository, or move it to a different machine, and things still work. For example, all the data and image references in these workbooks uses a relative path, so it works just fine on my Mac and your different computers without any issue. One important value when using relative paths is ../ which means "go up one level", so if we are in the "workbooks" folder here, we can use ../ to get to the root of the repository.
#
# ### Joining Paths
#
# When we need to deal with file paths we can use the os.path.join() function to join together the parts of the path. This is useful because it will automatically handle the differences between operating systems for us. For example, on a Mac the path separator is "/", while on a PC it is "\". The os.path.join() function will automatically use the correct separator for the operating system we are using.
#
# For example, to get the absolute path to a file, we can use the os.path.join() function to join together the current working directory and the relative path to the file.

# %%
file_name = "016_file_management_2.ipynb"
fold_path = os.getcwd()
print(f"File path: {os.path.join(fold_path, file_name)}")
# Out:
# File path: /Users/akeem/Nextcloud/GitHubReps/2024_summer/Instructor/Programming_Basics_for_ML/workbooks/016_file_management_2.ipynb

# %% [markdown]
# ## Reading and Writing Text Files
#
# Now that we have an idea what is in our folders, we can start recklessly changing things. For example, we can use the os write functions to make a new CSV file and write some data to it. One thing that is reveled to us here that might not be visible is you're used to Windows machines is a look at what is a "text" file. Text files are .txt, but also .csv, .tsv, .py, etc... meaning all of these types of files is made up of just plain text, and we can edit them in any text editor on a computer - the file extension doesn't dictate it, that's for our convenience. The structure of our code will:
# <ul>
# <li> Open a connection to the file, if it doesn't exist this will create it. </li>
# <li> Perform the contents of the loop - writing some data to a file for 100 lines. </li>
# <li> When that writing task is complete, it will close the connection automatically thanks to the with. </li>
# </ul>
#
# In the open() function call to connect to the file we provide the second argument that defines what type of access we get to the file we are opening:
# <ul>
# <b><li> 'r' - read only </li>
# <li> 'w' - write only </li>
# <li> 'a' - append to the end of the file </li>
# <li> 'r+' - read and write </li></b>
# <li> 'w+' - write and read, overwrites existing files</li>
# </ul>
#
# These are mostly pretty simple and self-explanatory, with the exception of the distinction between r+ and w. The 'r+' option is a bit more complicated. This will open the file for reading and writing, but it will not create the file if it doesn't exist. If you try to open a file that doesn't exist with 'r+' you will get an error. The `w` option will create the file if it doesn't exist, but it will also overwrite the file if it does exist. So if we are making something brand new, we want `w`, but if we are attempting to update an existing file, we want `r+`. This is an easy place to make an error, so we should be careful. We can also check to see if the file we want to make already exists, then make a decision. `W+` is another weird option, it is read/write, but will overwrite the file if it exists.
#
# ![File Permissions](../images/file_permissions.png "File Permissions" )
#
# Choosing the level of access of a file that we open is important in terms of writing our code to prevent errors. We want to open the file with the least impactful level of access that we need to have to do what we want. So if we are just reading data from a file, opening it as read only will prevent us accidentally changing that file in any way, as we don't even have the ability to do so. If we want a brand-new file, opening it as write only will prevent any old data that may have been hanging around from persisting. The more flexible the level of access, the more options we have for what we can do, the more likely it is that we may do something unintentional.
#
# <b>Note:</b> this will go to our current directory, wherever the pointer is, so if you got rid of that line to reset the locations, it would spit this file out to whatever folder you happen to be in.

# %% [markdown]
# #### Create a CSV with Fibonacci Numbers
#
# Here we'll make a CSV, fib.csv, that has two coulmns - an index and the fibonacci number at that index.

# %%
# write fibonacci series to a file
end_fib = 30

def fib(n):
    if n < 2:
        return n
    else:
        return fib(n-2) + fib(n-1)

with open("fib.csv", "w") as f:
    f.write("Index,Fibonacci Series\n")
    i = 0
    while i < end_fib:
        f.write(f"{i},{fib(i)}\n")
        #print(f"{i},{fib(i)}")
        i += 1
print("Done")
# Out:
# Done

# %% [markdown]
# #### Reading Our File
#
# Now that our file is written, we can read it and see what we got. We need to specify the `r` here, since we are only reading. When reading from a file, there's a few main options:
# <ul>
# <li> read() - read the entire file into a single string </li>
# <li> readline() - read the file one line at a time </li>
# <li> readlines() - read the file into a list of strings, one per line </li>
# </ul>
#
# The first, read, takes in the entire file into one string. This is fine for small files, but for things that are large it is unruly. For most things of size we probably want to navigate the file one line at a time, using the readline() option. There's also a common shortcut that we can do with a for loop that does this for us easily:
#
#     ``` for line in file: ```
#
# If we are reading in a large file, one line at a time is a better choice. Depending on what we are doing, we may be able to process our data and "deal with it" - whether that be saving it to another file or loading it into some dataset - on the fly. When we get to neural networks towards the end of machine learning, we'll try to read enough data so that our processor is busy - so the computer is never waiting for either data or a free processor. Loading batches allows us to make the most of the power of our computer, as we can minimize the amount of time any part of it spends waiting for something else to finish.

# %%
with open("fib.csv", "r") as f:
   for line in f:
      print(line)
# Out:
# Index,Fibonacci Series
#
# 0,0
#
# 1,1
#
# 2,1
#
# 3,2
#
# 4,3
#
# 5,5
#
# 6,8
#
# 7,13
#
# 8,21
#
# 9,34
#
# 10,55
#
# 11,89
#
# 12,144
#
# 13,233
#
# 14,377
#
# 15,610
#
# 16,987
#
# 17,1597
#
# 18,2584
#
# 19,4181
#
# 20,6765
#
# 21,10946
#
# 22,17711
#
# 23,28657
#
# 24,46368
#
# 25,75025
#
# 26,121393
#
# 27,196418
#
# 28,317811
#
# 29,514229

# %%
with open("fib.csv", "r") as f:
    fib_list = f.readlines()
print(fib_list)
# Out:
# ['Index,Fibonacci Series\n', '0,0\n', '1,1\n', '2,1\n', '3,2\n', '4,3\n', '5,5\n', '6,8\n', '7,13\n', '8,21\n', '9,34\n', '10,55\n', '11,89\n', '12,144\n', '13,233\n', '14,377\n', '15,610\n', '16,987\n', '17,1597\n', '18,2584\n', '19,4181\n', '20,6765\n', '21,10946\n', '22,17711\n', '23,28657\n', '24,46368\n', '25,75025\n', '26,121393\n', '27,196418\n', '28,317811\n', '29,514229\n']

# %% [markdown]
# We can also read it into a CSV, for fun!

# %%
df2 = pd.read_csv("fib.csv", index_col=None)
df2.head()
# Out:
#    Index  Fibonacci Series
# 0      0                 0
# 1      1                 1
# 2      2                 1
# 3      3                 2
# 4      4                 3

# %% [markdown]
# #### Seek
#
# When in a file, we can use the seek() function to move around. This is useful if we want to go back to the beginning of the file, or jump to a specific location. The seek() function takes in two arguments, the first is the location we want to go to, and the second is the reference point. The reference point can be 0, 1, or 2.
# <ul>
# <li>0 is the beginning of the file</li>
# <li>1 is the current location</li>
# <li>2 is the end of the file</li>
# </ul>
#
# So if we want to go to the beginning of the file, we can use seek(0,0). If we want to go to the end of the file, we can use seek(0,2). If we want to go to the 100th character in the file, we can use seek(100,0). If we want to go to the 100th character from the end of the file, we can use seek(-100,2).
#
# Note that in the examples below I've changed a couple of things - the open uses "rb" or "read binary" instead of "r" or "read". This is to allow us to do the offsets from the end or the current position - the system needs to deal with the binary file. Second, I've added that decode statement to the print statement. This is because the file is binary, so we need to decode it to get it into a string that we can print nicely. Note the last one - I didn't change the encoding. Text encoding is something we need to deal with, but something that is minor - we basically need to make sure that we are using the encoding that matches the file, or we need to re-encode it.
#
# #### Tell
#
# We can also use the tell() function to find out where we are in the file. This is useful if we want to jump around, but we don't know where we are. We can use tell() to find out where we are, then use seek() to go somewhere else.
#
# <b>Note:</b> the readline calls advance the pointer, so each readline is moving us ahead in the file from where the seek() command dropped us off.

# %%
# Open fib and seek/tell
with open("fib.csv", "rb") as f:
    print("At the stat of the file:")
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At position 150:")
    f.seek(150, 0)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At position 20, relative to the current position:")
    f.seek(0, os.SEEK_CUR)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At position 5:")
    f.seek(5, 0)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At the end:")
    f.seek(0, os.SEEK_END)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("Moving back from the end:")
    f.seek(-5, 2)
    print("Position", f.tell())
    print(f.readline())
# Out:
# At the stat of the file:
# Position 0
# Index,Fibonacci Series
#
# At position 150:
# Position 150
# 946
#
# At position 20, relative to the current position:
# Position 154
# 22,17711
#
# At position 5:
# Position 5
# ,Fibonacci Series
#
# At the end:
# Position 230
#
# Moving back from the end:
# Position 225
# b'4229\n'

# %% [markdown]
# #### Appending a File and the In-File Pointer
#
# Another of the options above that is a little odd is the `a`, for append. This will open the file and add new data to the end of it, but it will not overwrite the existing data. This is useful if we want to add new data to an existing file, but we don't want to lose the old data. This is very useful for things like logs - we likely have a pretty substantial amount of data accumulated in a big text file and we want to add new stuff without losing the old data or having to deal with the old data at all. We can use this to basically tack some entries onto the end of a file easily.
#
# This issue of opening an existing file normally vs appending seems pretty minor, but it can have larger performance implications than we might expect. For example, server logs can be many, many GB of text that lists errors or warnings going back years. We want to keep the log, and we also want to add today's entries. Opening a 2GB file "normally", navigating to the end, then spitting it back out can be slow, appending directly to the end of that same file is fast. This is because just like navigating a file system, a text file itself has a pointer that maintains your position - think of it as an invisible cursor just like we have in any program where we type. Append puts that position cursor directly at the end, and just starts writing. Personally, I once had a job where I remade a little program that went to approximately 150 servers, grabbed their log file, and looked for last night's entry at the end of the file to see if a backup failed. By changing it from opening the files normally, to appending (roughly, the language wasn't Python), I cut the runtime from 4 to 5 hours to about <10 minutes - without making any actual improvements to the logic of the code, just by jumping directly to the end of the text. When someone wrote the original, all the log files were probably tiny, as the system was new, so it didn't matter for performance; as things grew, this became an issue.
#
# <b>Note:</b> the "it's slow to open a large file and write to the end" thing is obviously a common issue for computers in general. File access packages know this, and are built to be fast no matter what. This idea is still true, just less true than it is with older software.

# %%
with open("fib.csv", "a") as f:
    print(f.tell())
# Out:
# 230

# %% [markdown]
# ## Exercise
#
# Complete the spotReader function to take in a file and a spot in that file, and return that line.

# %%
def spotReader(filepath, spot):
    ret_val = ""
    with open(filepath, "r") as f:
        f.seek(spot, 0)
        ret_val = f.readline()
    return ret_val

# %%
spotReader("fib.csv", 150)
# Out:
# '946\n'

# %% [markdown]
# ### Remote Data
#
# We can also use some code to programmatically download data from the internet. This can save us from having to download large files, but it can also help us to build automated pipelines for getting data.
#
# One thing that I've worked on a lot in industry is importing data from other systems into LMS systems like Moodle. A common process to do this is for the other system to export a CSV file to a specific location on a file server, then a script that we created will grab the new file from the pre-defined location and feed it into our import work. Applications for personal use are also broad - we could automate downloads of files that are regularly updated.
#
# For pretty much any data source that we might want to be able to access, there is likely a library that will do so. So we can access FTP servers, different file share protocols, and so on - we just need to look up the correct tool for whichever data source we want to access.
#
# <b>Note:</b> there are many libraries that download files, they're pretty much interchangeable. I'm using `urllib.request` here because it's built into Python and is the "basic standard", but you could also use `requests` or `wget` or `curl` or any number of other libraries. For this, and the others, look at the documentation to see the options and how to use the functions - they are generally similar to this, just provide a URL and a destination.

# %%
# Download
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
import urllib.request
try:
    urllib.request.urlretrieve(url, 'chipotle.tsv')
except:
    print("Error downloading file")

# %% [markdown]
# ### Compression
#
# Many files that we deal with, particularly when downloading datasets, may be compressed. Several libraries provide tools for us to programmatically deal with these files, including decompressing them and moving their files into our working directory.
#
# <b>Note:</b> Pandas read_csv function can also read compressed files directly, so you can load my_data.zip or similar with no interim decompression step.

# %%
# Compress some files
import zipfile

# Zip first 5 files in file_list
with zipfile.ZipFile('file_list.zip', 'w') as myzip:
    for file in range(5):
        myzip.write(file_list[file])

# %% [markdown]
# Decompress into a folder

# %%
# Decompress file_list.zip into file_list folder
with zipfile.ZipFile('file_list.zip', 'r') as myzip:
    myzip.extractall('file_list')

# %% [markdown]
# ## Exercise
#
# Create the function ipynb crawler. When given a director, assemble and return a list of all .ipynb files in that directory and all subdirectories.

# %%
def ipynbCrawler(directory_targ="../"):
    """
    Crawl a directory and return a list of all ipynb files
    """
    ipynb_list = []
    for root, directories, files in os.walk(directory_targ):
        for file in files:
            if file.endswith(".ipynb"):
                ipynb_list.append(os.path.join(root, file))
    return ipynb_list

# %%
ipynbCrawler()
# Out:
# ['../supplementary_practice_workbooks/Lecture23_24_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture22_Regression_Tuning.ipynb',
#  '../supplementary_practice_workbooks/Lecture18_beginning_classification_part_2.ipynb',
#  '../supplementary_practice_workbooks/Lecture_09_10_Workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture05_conditions_loops.ipynb',
#  '../supplementary_practice_workbooks/Lecture21_Multiple_Regression.ipynb',
#  '../supplementary_practice_workbooks/Lecture20_pipeline_part_2.ipynb',
#  '../supplementary_practice_workbooks/Lecture15_beginning_regression_part_1.ipynb',
#  '../supplementary_practice_workbooks/Lecture02_basics.ipynb',
#  '../supplementary_practice_workbooks/Lecture13-14_Intro_ML.ipynb',
#  '../supplementary_practice_workbooks/Lecture21_22_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture16_beginning_regression_part_2.ipynb',
#  '../supplementary_practice_workbooks/Lecture12_probability.ipynb',
#  '../supplementary_practice_workbooks/Lecture07-08_Pandas.ipynb',
#  '../supplementary_practice_workbooks/Lecture15-16_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture09_data_wrangling_pandas_I.ipynb',
#  '../supplementary_practice_workbooks/Lecture11_descriptive_statistics.ipynb',
#  '../supplementary_practice_workbooks/Lecture05_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture07-08_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture02_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture10_data_wrangling_pandas_II.ipynb',
#  '../supplementary_practice_workbooks/Lecture06_numpy.ipynb',
#  '../supplementary_practice_workbooks/Lecture03_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture04_arrays_files.ipynb',
#  '../supplementary_practice_workbooks/Lecture04_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture06_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture13_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture19_pipeline_impute_part_1.ipynb',
#  '../supplementary_practice_workbooks/Lecture23-24_classification_methods.ipynb',
#  '../supplementary_practice_workbooks/Lecture17_beginning_classification_part_1.ipynb',
#  '../supplementary_practice_workbooks/Lecture14_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture03_datatypes.ipynb',
#  '../supplementary_practice_workbooks/data_dictionary.ipynb',
#  '../supplementary_practice_workbooks/Lecture11_12_Workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture19_20_workbook.ipynb',
#  '../supplementary_practice_workbooks/Lecture17_18_Workbook.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/2_Examples.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/4_Day_1.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/1_racing cars.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/1_exapmles.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/2_Day_1.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/11_Inheritance_.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/6 Day 1 - Lists and Functions.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/2_More Exercises.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/Week_9_Day_Sets_and_Dictionaries.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/10_Day_1_Object_Oriented_Programming.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/7_Day_1_Files_and_exceptions.ipynb',
#  '../supplementary_practice_workbooks/moodle_exercises/3 Day 1.ipynb',
#  '../course_material/labs/lab1/generate_tests.ipynb',
#  '../course_material/labs/lab1/SAMP_SOL_Lab_1.ipynb',
#  '../course_material/labs/lab6/SAMP_SOL_Lab_6.ipynb',
#  '../course_material/labs/lab5/SAMP_SOL_Lab_5.ipynb',
#  '../course_material/labs/lab2/SAMP_SOL_Lab_2.ipynb',
#  '../course_material/labs/lab3/SAMP_SOL_Lab_3.ipynb',
#  '../course_material/labs/lab4/SAMP_SOL_Lab_4.ipynb',
#  '../course_material/assignments/asn1/START_Asn_1.ipynb',
#  '../course_material/assignments/asn1/Asn_1_1241.ipynb',
#  '../course_material/assignments/asn1/Assignment_1_sample_sol.ipynb',
#  '../course_material/assignments/asn2/START_Asn_2.ipynb',
#  '../workbooks/002_conditional_statements_sol.ipynb',
#  '../workbooks/021_big_review.ipynb',
#  '../workbooks/010_class_comments.ipynb',
#  '../workbooks/011_looping_2_data.ipynb',
#  '../workbooks/001_programming_basics_sol.ipynb',
#  '../workbooks/017a_cards_sol.ipynb',
#  '../workbooks/020_string_processing_regex_sol.ipynb',
#  '../workbooks/025_refactor_cards_gui.ipynb',
#  '../workbooks/005_file_access.ipynb',
#  '../workbooks/007_other_data_structures_full_sol.ipynb',
#  '../workbooks/018_cards_part_2.ipynb',
#  '../workbooks/019_cards_3_import.ipynb',
#  '../workbooks/017_inheritance.ipynb',
#  '../workbooks/006_objects.ipynb',
#  '../workbooks/012_algorithm_design_sol.ipynb',
#  '../workbooks/017_inheritance_sol.ipynb',
#  '../workbooks/002_conditional_statements.ipynb',
#  '../workbooks/004_functions_sol.ipynb',
#  '../workbooks/003_loops_sol.ipynb',
#  '../workbooks/023_search_sort.ipynb',
#  '../workbooks/005a_File_Loading_example_from_stats.ipynb',
#  '../workbooks/004_functions.ipynb',
#  '../workbooks/009_strings_sol.ipynb',
#  '../workbooks/016_file_management_2.ipynb',
#  '../workbooks/024_cards_ipython.ipynb',
#  '../workbooks/018_cards_part_2_sol.ipynb',
#  '../workbooks/013_arrays_and_numpy_sol.ipynb',
#  '../workbooks/009_strings.ipynb',
#  '../workbooks/011_looping_2_data_sol.ipynb',
#  '../workbooks/025_refactor_cards_gui_sol.ipynb',
#  '../workbooks/014_map_apply.ipynb',
#  '../workbooks/022_abstract_multip_inh.ipynb',
#  '../workbooks/014_map_apply_sol.ipynb',
#  '../workbooks/006_objects_sol.ipynb',
#  '../workbooks/017_args_kwargs.ipynb',
#  '../workbooks/023_search_sort_sol.ipynb',
#  '../workbooks/018_cards_part_2_akeem_in_class.ipynb',
#  '../workbooks/012_algorithm_design.ipynb',
#  '../workbooks/020_string_processing_regex.ipynb',
#  '../workbooks/024_cards_ipython_sol.ipynb',
#  '../workbooks/022_abstract_multip_inh_sol.ipynb',
#  '../workbooks/013_arrays_and_numpy.ipynb',
#  '../workbooks/016_file_management_2_sol.ipynb',
#  '../workbooks/000_Setup.ipynb',
#  '../workbooks/015_overloading_sol.ipynb',
#  '../workbooks/019_cards_3_import_sol.ipynb',
#  '../workbooks/001_programming_basics.ipynb',
#  '../workbooks/008_recursion_sol.ipynb',
#  '../workbooks/017_args_kwargs_sol.ipynb',
#  '../workbooks/007_other_data_structures.ipynb',
#  '../workbooks/003_loops.ipynb',
#  '../workbooks/017a_cards.ipynb',
#  '../workbooks/005_file_access_sol.ipynb',
#  '../workbooks/015_overloading.ipynb',
#  '../workbooks/008_recursion.ipynb',
#  '../workbooks/file_list/002_conditional_statements_sol.ipynb',
#  '../workbooks/file_list/021_big_review.ipynb',
#  '../workbooks/file_list/010_class_comments.ipynb',
#  '../workbooks/file_list/011_looping_2_data.ipynb',
#  '../workbooks/zz_OLD/dl_process.ipynb',
#  '../workbooks/zz_OLD/file_list/002_conditional_statements_sol.ipynb',
#  '../workbooks/zz_OLD/file_list/021_big_review.ipynb',
#  '../workbooks/zz_OLD/file_list/010_class_comments.ipynb',
#  '../workbooks/zz_OLD/file_list/011_looping_2_data.ipynb',
#  '../workbooks/zz_OLD/file_list/005_file_access.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/010_class_comments.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/017a_cards_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/020_string_processing_regex_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/005_file_access.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/006_objects.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/002_conditional_statements.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/z00_classes.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/overloading_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/005a_File_Loading_example_from_stats.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/004_functions.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/009_strings_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/cards_3_import_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/024_cards_ipython.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/018_cards_part_2_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/abstract_class.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/013_arrays_and_numpy_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/021_big_review_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/inheritance.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/poker_gui.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/011_looping_2_data_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/025_refactor_cards_gui_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/car.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/014_map_apply_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/012_algorithm_design.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/date_data_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/multip_inh.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/022_abstract_multip_inh_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/016_file_management_2_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/000_Setup.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/023_functional.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/tmp.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/001_programming_basics.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/arrays_and_numpy_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/search_sort.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/string_processing.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/017_args_kwargs_sol.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/007_other_data_structures.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/003_loops.ipynb',
#  '../workbooks/zz_OLD/development_working_dir/008_recursion.ipynb']
